# %%
# %precision 3
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sl
import scipy.sparse as sp
import scipy.sparse.linalg as spla
# the following allows us to plot triangles indicating convergence order
from matplotlib import cm
# and we will create some animations!
import matplotlib.animation as animation
from IPython.display import HTML
from pprint import pprint

# %% [markdown]
# # Question 2
# # a) Solving the flow simulation
# ### Define the pressure solver

# %%
def pressure_poisson_jacobi(p, dx, dy, RHS, rtol = 1.e-5, logs = False):
    """ Solve the pressure Poisson equation (PPE)
    using Jacobi iteration assuming mesh spacing of
    dx and dy (we assume at the moment that dx=dy)
    and the RHS function given by RHS.
    
    Assumes imposition of a Neumann BC on all boundaries.
    
    Return the pressure field.
    """
    # iterate
    tol = 10.*rtol
    it = 0
    p_old = np.copy(p)
    imax = len(p)
    jmax = np.size(p)//imax
    while tol > rtol:
        it += 1
        
        #swap arrays without copying the data
        temp = p_old
        p_old = p
        p = temp
        
        #this version is valid for dx!=dy
        p[1:-1, 1:-1] = 1.0/(2.0+2.0*(dx**2)/(dy**2))*(p_old[2:, 1:-1] + p_old[:-2, 1:-1] +
                                (p_old[1:-1, 2:] + p_old[1:-1,:-2])*(dx**2)/(dy**2)
                                - (dx**2)*RHS[1:-1, 1:-1])
        
        # apply zero gradient Neumann boundary conditions at the no slip walls    
        p[1:-1, 0] = p[1:-1, 1]
        p[-1,1:-1] = p[-2,1:-1]
        #p[0, :-(jmax-jmax//2) + 1] = p[1, :-(jmax-jmax//2) + 1]
        p[:-(imax-imax//2) + 1, -1] = p[:-(imax-imax//2) + 1, -2] #Top wall

        # relative change in pressure
        tol = sl.norm(p - p_old)/np.maximum(1.0e-10,sl.norm(p))
        
    if logs: print('pressure solve iterations = {:4d}'.format(it))
    return p

# %% [markdown]
# ### Supplymentry function

# %%
def calculate_ppm_RHS_upwind(rho, u, v, RHS, dt, dx, dy):
    """ Calculate the RHS of the 
    Poisson equation resulting from the projection method.
    Use upwind differences for the first derivatives of u and v.
    """
    RHS[1:-1, 1:-1] =rho*(np.select([u[1:-1, 1:-1] > 0, u[1:-1, 1:-1] < 0],
                      [np.diff(u[:-1, 1:-1], n=1, axis=0)/dx,
                       np.diff(u[1:, 1:-1], n=1, axis=0)/dx]) + 
              np.select([v[1:-1, 1:-1] > 0, v[1:-1, 1:-1] < 0],
                      [np.diff(v[1:-1, :-1], n=1, axis=1)/dy,
                       np.diff(v[1:-1, 1:], n=1, axis=1)/dy]))
    return RHS

def calculate_ppm_RHS_central(rho, u, v, RHS, dt, dx, dy):
    """ Calculate the RHS of the 
    Poisson equation resulting from the projection method.
    Use central differences for the first derivatives of u and v.
    """
    RHS[1:-1, 1:-1] = rho * (
        (1.0/dt) * ( (u[2:, 1:-1] - u[:-2, 1:-1]) / (2*dx) 
                   + (v[1:-1, 2:] - v[1:-1, :-2]) / (2*dy) ))
    return RHS

def project_velocity(rho, u, v, dt, dx, dy, p):
    """ Update the velocity to be divergence free using the pressure.
    """
    u[1:-1, 1:-1] = u[1:-1, 1:-1] - dt * (1./rho) * (
        (p[2:, 1:-1] - p[:-2, 1:-1])/(2*dx) )
    v[1:-1, 1:-1] = v[1:-1, 1:-1] - dt * (1./rho) * (
        (p[1:-1, 2:] - p[1:-1, :-2])/(2*dy) )
    
    #apply the velocity boundary condition to the projected velocity data
    imax = len(u)
    jmax = np.size(u)//imax
    u[0,:] = u[1,:]
    v[imax//2:,-1] = v[imax//2:,-2]
    
    return u, v

def calculate_intermediate_velocity(nu, u, v, u_old, v_old, dt, dx, dy):
    """ Calculate the intermediate velocities.
    """
    # intermediate u
    u[1:-1, 1:-1] = u_old[1:-1, 1:-1] - dt * (
                      # ADVECTION:  uu_x + vu_x
                        u_old[1:-1, 1:-1] *
                      # see comments in the upwind based solver for advection above
                      np.select([u_old[1:-1, 1:-1] > 0, u_old[1:-1, 1:-1] < 0],
                      [np.diff(u_old[:-1, 1:-1], n=1, axis=0)/dx,
                       np.diff(u_old[1:, 1:-1], n=1, axis=0)/dx]) +
                             v_old[1:-1, 1:-1] *
                       np.select([v_old[1:-1, 1:-1] > 0, v_old[1:-1, 1:-1] < 0],
                      [np.diff(u_old[1:-1, :-1], n=1, axis=1)/dy,
                       np.diff(u_old[1:-1, 1:], n=1, axis=1)/dy]) ) + (
                       # DIFFUSION
                         dt*nu*(np.diff(u_old[:, 1:-1], n=2, axis=0)/(dx**2)
                                 + np.diff(u_old[1:-1, :], n=2, axis=1)/(dy**2)) )
    # intermediate v
    v[1:-1, 1:-1] = v_old[1:-1, 1:-1] - dt * (
                      # ADVECTION:  uv_x + vv_x
                        u_old[1:-1, 1:-1] *
                      np.select([u_old[1:-1, 1:-1] > 0, u_old[1:-1, 1:-1] < 0],
                      [np.diff(v_old[:-1, 1:-1], n=1, axis=0)/dx,
                       np.diff(v_old[1:, 1:-1], n=1, axis=0)/dx]) +
                             v_old[1:-1, 1:-1] *
                       np.select([v_old[1:-1, 1:-1] > 0, v_old[1:-1, 1:-1] < 0],
                      [np.diff(v_old[1:-1, :-1], n=1, axis=1)/dy,
                       np.diff(v_old[1:-1, 1:], n=1, axis=1)/dy]) ) + (
                       # DIFFUSION
                        dt*nu*(np.diff(v_old[:, 1:-1], n=2, axis=0)/(dx**2)
                                 + np.diff(v_old[1:-1, :], n=2, axis=1)/(dy**2)) )
    
    return u, v

# %% [markdown]
# ### My function for stopping criteria when reach steady states

# %%
def has_reached_steady_state(old_field, new_field, tolerance=1e-8):
    """
    Check if the simulation has reached a steady state by comparing the change in field values.
    
    Parameters:
    old_field : numpy.ndarray
        The field values at the previous time step.
    new_field : numpy.ndarray
        The field values at the current time step.
    tolerance : float
        The threshold below which the system is considered to have reached a steady state.
    
    Returns:
    bool
        True if the system is at steady state, False otherwise.
    """
    return np.all(np.abs(new_field - old_field) < tolerance)

# %% [markdown]
# ### The updated Navier-stokes solver with boundary updation and steady state detection

# %%
def solve_NS(u, v, p, rho, nu, courant, dt_min, t_end, dx, dy, rtol = 1.e-5, logs = False, outint = 100):
    """ Solve the incompressible Navier-Stokes equations
    using a lot of the numerical choices and approaches we've seen
    earlier in this lecture.
    """
    t = 0
    
    u_old = u.copy()
    v_old = v.copy()
    p_RHS = np.zeros_like(X)
    
    time_it = 0 
    
    steady_state_reached = False
    while t < t_end and not steady_state_reached:
        time_it+=1
        #set dt based on courant number
        vel_max = np.max(np.sqrt(u**2+v**2))
        if vel_max>0.0:
            dt = min(courant*min(dx,dy)/vel_max,dt_min)
        else:
            dt = dt_min
            
        t += dt
        if logs and time_it%outint == 0: 
            print('\nTime = {:.8f}'.format(t))
            
        # calculate intermediate velocities
        u, v = calculate_intermediate_velocity(nu, u, v, u_old, v_old, dt, dx, dy)
        # PPM
        # calculate RHS for the pressure Poisson problem
        p_RHS = calculate_ppm_RHS_central(rho, u, v, p_RHS, dt, dx, dy)
        # compute pressure - note that we use the previous p as an initial guess to the solution
        p = pressure_poisson_jacobi(p, dx, dy, p_RHS, 1.e-5, logs = (logs and time_it%outint == 0))
        # project velocity
        u, v = project_velocity(rho, u, v, dt, dx, dy, p)
        
        if logs and time_it%outint == 0:
            print('norm(u) = {0:.8f}, norm(v) = {1:.8f}'.format(sl.norm(u),sl.norm(v)))
            print('Courant number: {0:.8f}'.format(np.max(np.sqrt(u**2+v**2)) * dt / min(dx,dy)))
                
        #swap pointers without copying data
        temp = u_old
        u_old = u
        u = temp
        temp = v_old
        v_old = v
        v = temp

        steady_state_reached = has_reached_steady_state(u_old, u) and \
                       has_reached_steady_state(v_old, v)
        
        if(steady_state_reached):
            print("Steady state reached at time: ", t)

    return u, v, p

# %% [markdown]
# ### Define required physical parameters and initialize gird and inital boundary condition

# %%
# physical parameters
rho = 1000
nu = 0.001/1000.

# define spatial mesh
# Size of rectangular domain
Lx = 0.01
Ly = 0.005
P_max = 0.5

# Number of grid points in each direction, including boundary nodes
Nx = 101
Ny = 76

# hence the mesh spacing
dx = Lx/(Nx-1)
dy = Ly/(Ny-1)

# read the docs to see the ordering that mgrid gives us
X, Y = np.mgrid[0:Nx:1, 0:Ny:1]
X = dx*X
Y = dy*Y
# the following is an alternative to the three lines above
#X, Y = np.mgrid[0: Lx + 1e-10: dx, 0: Ly + 1e-10: dy]
# but without the need to add a "small" increement to ensure
# the Lx and Ly end points are included

# initialise independent variables
u = np.zeros_like(X)
v = np.zeros_like(X)
p = np.zeros_like(X)

# Apply Dirichlet BCs to u and v - the code below doesn't touch 
# these so we can do this once outside the time loop
u[:, -1] = 0
u[:, 0] = 0
u[0, :] = 0
u[-1, :] = 0
v[:, -1] = 0
v[:, 0] = 0
v[0, :] = 0
v[-1, :] = 0
imax = len(u)
jmax = np.size(u)//imax
p[0,] = P_max
p[imax//2:, -1] = 0.0

#set a Courant number and use dynamic time step
courant = 0.005
dt_min = 1.e-4

t_end = 10

# %% [markdown]
# ### Run the simulation

# %%
import time
start = time.time()
u, v, p = solve_NS(u, v, p, rho, nu, courant, dt_min, t_end, dx, dy, rtol=1.e-6, logs = True, outint = 1000)
end = time.time()
print('Time taken by calculation = ', end - start)
# Out:
# Time = 0.06380770
# pressure solve iterations =    2
# norm(u) = 0.26323235, norm(v) = 0.12870711
# Courant number: 0.00500420
#
# Time = 0.09894732
# pressure solve iterations =    3
# norm(u) = 0.39822013, norm(v) = 0.19235762
# Courant number: 0.00500206
#
# Time = 0.12733738
# pressure solve iterations =    3
# norm(u) = 0.50361365, norm(v) = 0.24091704
# Courant number: 0.00500131
#
# Time = 0.15215100
# pressure solve iterations =    2
# norm(u) = 0.59328520, norm(v) = 0.28159729
# Courant number: 0.00500099
#
# Time = 0.17464164
# pressure solve iterations =    2
# norm(u) = 0.67264048, norm(v) = 0.31721730
# Courant number: 0.00500076
#
# Time = 0.19546137
# pressure solve iterations =    3
# norm(u) = 0.74445003, norm(v) = 0.34921086
# Courant number: 0.00500064
#
# Time = 0.21499001
# pressure solve iterations =    2
# norm(u) = 0.81031146, norm(v) = 0.37839441
# Courant number: 0.00500056
#
# Time = 0.23346437
# pressure solve iterations =    3
# norm(u) = 0.87121924, norm(v) = 0.40526710
# Courant number: 0.00500048
#
# Time = 0.25105930
# pressure solve iterations =    3
# norm(u) = 0.92789551, norm(v) = 0.43017985
# Courant number: 0.00500043
#
# Time = 0.26790906
# pressure solve iterations =    3
# norm(u) = 0.98088812, norm(v) = 0.45339039
# Courant number: 0.00500038
#
# Time = 0.28412677
# pressure solve iterations =    2
# norm(u) = 1.03064840, norm(v) = 0.47510453
# Courant number: 0.00500034
#
# Time = 0.29979025
# pressure solve iterations =    3
# norm(u) = 1.07749792, norm(v) = 0.49546566
# Courant number: 0.00500032
#
# Time = 0.31495720
# pressure solve iterations =    2
# norm(u) = 1.12168572, norm(v) = 0.51458273
# Courant number: 0.00500029
#
# Time = 0.32968206
# pressure solve iterations =    3
# norm(u) = 1.16344295, norm(v) = 0.53255580
# Courant number: 0.00500028
#
# Time = 0.34400540
# pressure solve iterations =    2
# norm(u) = 1.20295371, norm(v) = 0.54946421
# Courant number: 0.00500026
#
# Time = 0.35796124
# pressure solve iterations =    3
# norm(u) = 1.24037856, norm(v) = 0.56537754
# Courant number: 0.00500024
#
# Time = 0.37158325
# pressure solve iterations =    2
# norm(u) = 1.27587222, norm(v) = 0.58036352
# Courant number: 0.00500022
#
# Time = 0.38490239
# pressure solve iterations =    2
# norm(u) = 1.30957632, norm(v) = 0.59448493
# Courant number: 0.00500021
#
# Time = 0.39794245
# pressure solve iterations =    2
# norm(u) = 1.34160871, norm(v) = 0.60779513
# Courant number: 0.00500020
#
# Time = 0.41072203
# pressure solve iterations =    2
# norm(u) = 1.37207008, norm(v) = 0.62034095
# Courant number: 0.00500019
#
# Time = 0.42325955
# pressure solve iterations =    2
# norm(u) = 1.40105695, norm(v) = 0.63216805
# Courant number: 0.00500018
#
# Time = 0.43556960
# pressure solve iterations =    2
# norm(u) = 1.42865304, norm(v) = 0.64331729
# Courant number: 0.00500017
#
# Time = 0.44766887
# pressure solve iterations =    1
# norm(u) = 1.45494343, norm(v) = 0.65383033
# Courant number: 0.00500016
#
# Time = 0.45957209
# pressure solve iterations =    1
# norm(u) = 1.48000489, norm(v) = 0.66374551
# Courant number: 0.00500016
#
# Time = 0.47128931
# pressure solve iterations =    2
# norm(u) = 1.50390090, norm(v) = 0.67309578
# Courant number: 0.00500015
#
# Time = 0.48283093
# pressure solve iterations =    1
# norm(u) = 1.52669321, norm(v) = 0.68191333
# Courant number: 0.00500015
#
# Time = 0.49420438
# pressure solve iterations =    2
# norm(u) = 1.54843531, norm(v) = 0.69022688
# Courant number: 0.00500014
#
# Time = 0.50541798
# pressure solve iterations =    1
# norm(u) = 1.56918049, norm(v) = 0.69806484
# Courant number: 0.00500014
#
# Time = 0.51647933
# pressure solve iterations =    1
# norm(u) = 1.58897874, norm(v) = 0.70545393
# Courant number: 0.00500013
#
# Time = 0.52739766
# pressure solve iterations =    1
# norm(u) = 1.60788097, norm(v) = 0.71242086
# Courant number: 0.00500012
#
# Time = 0.53818128
# pressure solve iterations =    1
# norm(u) = 1.62593425, norm(v) = 0.71899035
# Courant number: 0.00500012
#
# Time = 0.54883585
# pressure solve iterations =    1
# norm(u) = 1.64317909, norm(v) = 0.72518414
# Courant number: 0.00500012
#
# Time = 0.55936791
# pressure solve iterations =    1
# norm(u) = 1.65965604, norm(v) = 0.73102355
# Courant number: 0.00500011
#
# Time = 0.56978427
# pressure solve iterations =    1
# norm(u) = 1.67540429, norm(v) = 0.73652901
# Courant number: 0.00500011
#
# Time = 0.58009122
# pressure solve iterations =    1
# norm(u) = 1.69046056, norm(v) = 0.74171944
# Courant number: 0.00500010
#
# Time = 0.59029430
# pressure solve iterations =    1
# norm(u) = 1.70485890, norm(v) = 0.74661213
# Courant number: 0.00500010
#
# Time = 0.60039735
# pressure solve iterations =    1
# norm(u) = 1.71862942, norm(v) = 0.75122271
# Courant number: 0.00500009
#
# Time = 0.61040530
# pressure solve iterations =    1
# norm(u) = 1.73180264, norm(v) = 0.75556663
# Courant number: 0.00500009
#
# Time = 0.62032300
# pressure solve iterations =    1
# norm(u) = 1.74440761, norm(v) = 0.75965839
# Courant number: 0.00500009
#
# Time = 0.63015494
# pressure solve iterations =    1
# norm(u) = 1.75647160, norm(v) = 0.76351157
# Courant number: 0.00500008
#
# Time = 0.63990531
# pressure solve iterations =    1
# norm(u) = 1.76802028, norm(v) = 0.76713882
# Courant number: 0.00500008
#
# Time = 0.64957708
# pressure solve iterations =    1
# norm(u) = 1.77907666, norm(v) = 0.77055162
# Courant number: 0.00500008
#
# Time = 0.65917353
# pressure solve iterations =    1
# norm(u) = 1.78966325, norm(v) = 0.77376104
# Courant number: 0.00500008
#
# Time = 0.66869821
# pressure solve iterations =    1
# norm(u) = 1.79980187, norm(v) = 0.77677763
# Courant number: 0.00500007
#
# Time = 0.67815371
# pressure solve iterations =    1
# norm(u) = 1.80951230, norm(v) = 0.77961107
# Courant number: 0.00500007
#
# Time = 0.68754286
# pressure solve iterations =    1
# norm(u) = 1.81881382, norm(v) = 0.78227064
# Courant number: 0.00500007
#
# Time = 0.69686870
# pressure solve iterations =    1
# norm(u) = 1.82772502, norm(v) = 0.78476523
# Courant number: 0.00500007
#
# Time = 0.70613407
# pressure solve iterations =    1
# norm(u) = 1.83626350, norm(v) = 0.78710318
# Courant number: 0.00500006
#
# Time = 0.71534166
# pressure solve iterations =    1
# norm(u) = 1.84444591, norm(v) = 0.78929238
# Courant number: 0.00500006
#
# Time = 0.72449398
# pressure solve iterations =    1
# norm(u) = 1.85228799, norm(v) = 0.79134025
# Courant number: 0.00500006
#
# Time = 0.73359342
# pressure solve iterations =    1
# norm(u) = 1.85980468, norm(v) = 0.79325381
# Courant number: 0.00500006
#
# Time = 0.74264223
# pressure solve iterations =    1
# norm(u) = 1.86701014, norm(v) = 0.79503970
# Courant number: 0.00500005
#
# Time = 0.75164254
# pressure solve iterations =    1
# norm(u) = 1.87391782, norm(v) = 0.79670420
# Courant number: 0.00500005
#
# Time = 0.76059636
# pressure solve iterations =    1
# norm(u) = 1.88054049, norm(v) = 0.79825325
# Courant number: 0.00500005
#
# Time = 0.76950559
# pressure solve iterations =    1
# norm(u) = 1.88689030, norm(v) = 0.79969251
# Courant number: 0.00500005
#
# Time = 0.77837205
# pressure solve iterations =    1
# norm(u) = 1.89297880, norm(v) = 0.80102732
# Courant number: 0.00500005
#
# Time = 0.78719745
# pressure solve iterations =    1
# norm(u) = 1.89881698, norm(v) = 0.80226276
# Courant number: 0.00500004
#
# Time = 0.79598341
# pressure solve iterations =    1
# norm(u) = 1.90441533, norm(v) = 0.80340365
# Courant number: 0.00500004
#
# Time = 0.80473120
# pressure solve iterations =    1
# norm(u) = 1.90978362, norm(v) = 0.80445454
# Courant number: 0.00500004
#
# Time = 0.81344215
# pressure solve iterations =    1
# norm(u) = 1.91493130, norm(v) = 0.80541977
# Courant number: 0.00500004
#
# Time = 0.82211768
# pressure solve iterations =    1
# norm(u) = 1.91986751, norm(v) = 0.80630351
# Courant number: 0.00500004
#
# Time = 0.83075916
# pressure solve iterations =    1
# norm(u) = 1.92460097, norm(v) = 0.80710974
# Courant number: 0.00500004
#
# Time = 0.83936787
# pressure solve iterations =    1
# norm(u) = 1.92913999, norm(v) = 0.80784223
# Courant number: 0.00500004
#
# Time = 0.84794504
# pressure solve iterations =    1
# norm(u) = 1.93349253, norm(v) = 0.80850459
# Courant number: 0.00500004
#
# Time = 0.85649187
# pressure solve iterations =    1
# norm(u) = 1.93766615, norm(v) = 0.80910023
# Courant number: 0.00500003
#
# Time = 0.86500946
# pressure solve iterations =    1
# norm(u) = 1.94166810, norm(v) = 0.80963242
# Courant number: 0.00500003
#
# Time = 0.87349889
# pressure solve iterations =    1
# norm(u) = 1.94550531, norm(v) = 0.81010428
# Courant number: 0.00500003
#
# Time = 0.88196118
# pressure solve iterations =    1
# norm(u) = 1.94918441, norm(v) = 0.81051877
# Courant number: 0.00500003
#
# Time = 0.89039731
# pressure solve iterations =    1
# norm(u) = 1.95271172, norm(v) = 0.81087873
# Courant number: 0.00500003
#
# Time = 0.89880822
# pressure solve iterations =    1
# norm(u) = 1.95609330, norm(v) = 0.81118687
# Courant number: 0.00500003
#
# Time = 0.90719481
# pressure solve iterations =    1
# norm(u) = 1.95933496, norm(v) = 0.81144575
# Courant number: 0.00500003
#
# Time = 0.91555792
# pressure solve iterations =    1
# norm(u) = 1.96244225, norm(v) = 0.81165785
# Courant number: 0.00500003
#
# Time = 0.92389838
# pressure solve iterations =    1
# norm(u) = 1.96542047, norm(v) = 0.81182552
# Courant number: 0.00500003
#
# Time = 0.93221698
# pressure solve iterations =    1
# norm(u) = 1.96827474, norm(v) = 0.81195101
# Courant number: 0.00500003
#
# Time = 0.94051447
# pressure solve iterations =    1
# norm(u) = 1.97100992, norm(v) = 0.81203645
# Courant number: 0.00500002
#
# Time = 0.94879157
# pressure solve iterations =    1
# norm(u) = 1.97363068, norm(v) = 0.81208391
# Courant number: 0.00500002
#
# Time = 0.95704897
# pressure solve iterations =    1
# norm(u) = 1.97614152, norm(v) = 0.81209535
# Courant number: 0.00500002
#
# Time = 0.96528735
# pressure solve iterations =    1
# norm(u) = 1.97854673, norm(v) = 0.81207263
# Courant number: 0.00500002
#
# Time = 0.97350734
# pressure solve iterations =    1
# norm(u) = 1.98085042, norm(v) = 0.81201754
# Courant number: 0.00500002
#
# Time = 0.98170955
# pressure solve iterations =    1
# norm(u) = 1.98305654, norm(v) = 0.81193181
# Courant number: 0.00500002
#
# Time = 0.98989457
# pressure solve iterations =    1
# norm(u) = 1.98516888, norm(v) = 0.81181705
# Courant number: 0.00500002
#
# Time = 0.99806297
# pressure solve iterations =    1
# norm(u) = 1.98719108, norm(v) = 0.81167484
# Courant number: 0.00500002
#
# Time = 1.00621530
# pressure solve iterations =    1
# norm(u) = 1.98912662, norm(v) = 0.81150668
# Courant number: 0.00500002
#
# Time = 1.01435207
# pressure solve iterations =    1
# norm(u) = 1.99097885, norm(v) = 0.81131398
# Courant number: 0.00500002
#
# Time = 1.02247380
# pressure solve iterations =    1
# norm(u) = 1.99275098, norm(v) = 0.81109812
# Courant number: 0.00500002
#
# Time = 1.03058096
# pressure solve iterations =    1
# norm(u) = 1.99444609, norm(v) = 0.81086041
# Courant number: 0.00500002
#
# Time = 1.03867402
# pressure solve iterations =    1
# norm(u) = 1.99606714, norm(v) = 0.81060209
# Courant number: 0.00500002
#
# Time = 1.04675343
# pressure solve iterations =    1
# norm(u) = 1.99761697, norm(v) = 0.81032435
# Courant number: 0.00500002
#
# Time = 1.05481963
# pressure solve iterations =    1
# norm(u) = 1.99909830, norm(v) = 0.81002834
# Courant number: 0.00500002
#
# Time = 1.06287303
# pressure solve iterations =    1
# norm(u) = 2.00051377, norm(v) = 0.80971515
# Courant number: 0.00500002
#
# Time = 1.07091403
# pressure solve iterations =    1
# norm(u) = 2.00186588, norm(v) = 0.80938583
# Courant number: 0.00500001
#
# Time = 1.07894302
# pressure solve iterations =    1
# norm(u) = 2.00315706, norm(v) = 0.80904136
# Courant number: 0.00500001
#
# Time = 1.08696038
# pressure solve iterations =    1
# norm(u) = 2.00438961, norm(v) = 0.80868272
# Courant number: 0.00500001
#
# Time = 1.09496646
# pressure solve iterations =    1
# norm(u) = 2.00556579, norm(v) = 0.80831079
# Courant number: 0.00500001
#
# Time = 1.10296161
# pressure solve iterations =    1
# norm(u) = 2.00668773, norm(v) = 0.80792646
# Courant number: 0.00500001
#
# Time = 1.11094617
# pressure solve iterations =    1
# norm(u) = 2.00775749, norm(v) = 0.80753057
# Courant number: 0.00500001
#
# Time = 1.11892045
# pressure solve iterations =    1
# norm(u) = 2.00877705, norm(v) = 0.80712390
# Courant number: 0.00500001
#
# Time = 1.12688478
# pressure solve iterations =    1
# norm(u) = 2.00974832, norm(v) = 0.80670721
# Courant number: 0.00500001
#
# Time = 1.13483946
# pressure solve iterations =    1
# norm(u) = 2.01067312, norm(v) = 0.80628123
# Courant number: 0.00500001
#
# Time = 1.14278477
# pressure solve iterations =    1
# norm(u) = 2.01155323, norm(v) = 0.80584666
# Courant number: 0.00500001
#
# Time = 1.15072099
# pressure solve iterations =    1
# norm(u) = 2.01239032, norm(v) = 0.80540416
# Courant number: 0.00500001
#
# Time = 1.15864841
# pressure solve iterations =    1
# norm(u) = 2.01318604, norm(v) = 0.80495436
# Courant number: 0.00500001
#
# Time = 1.16656728
# pressure solve iterations =    1
# norm(u) = 2.01394194, norm(v) = 0.80449786
# Courant number: 0.00500001
#
# Time = 1.17447785
# pressure solve iterations =    1
# norm(u) = 2.01465953, norm(v) = 0.80403525
# Courant number: 0.00500001
#
# Time = 1.18238038
# pressure solve iterations =    1
# norm(u) = 2.01534026, norm(v) = 0.80356707
# Courant number: 0.00500001
#
# Time = 1.19027510
# pressure solve iterations =    1
# norm(u) = 2.01598553, norm(v) = 0.80309384
# Courant number: 0.00500001
#
# Time = 1.19816223
# pressure solve iterations =    1
# norm(u) = 2.01659667, norm(v) = 0.80261608
# Courant number: 0.00500001
#
# Time = 1.20604201
# pressure solve iterations =    1
# norm(u) = 2.01717498, norm(v) = 0.80213425
# Courant number: 0.00500001
#
# Time = 1.21391465
# pressure solve iterations =    1
# norm(u) = 2.01772169, norm(v) = 0.80164882
# Courant number: 0.00500001
#
# Time = 1.22178035
# pressure solve iterations =    1
# norm(u) = 2.01823801, norm(v) = 0.80116021
# Courant number: 0.00500001
#
# Time = 1.22963930
# pressure solve iterations =    1
# norm(u) = 2.01872508, norm(v) = 0.80066885
# Courant number: 0.00500001
#
# Time = 1.23749157
# pressure solve iterations =    1
# norm(u) = 2.01918399, norm(v) = 0.80017513
# Courant number: 0.00500001
#
# Time = 1.24533731
# pressure solve iterations =    1
# norm(u) = 2.01961580, norm(v) = 0.79967943
# Courant number: 0.00500001
#
# Time = 1.25317670
# pressure solve iterations =    1
# norm(u) = 2.02002156, norm(v) = 0.79918212
# Courant number: 0.00500001
#
# Time = 1.26100993
# pressure solve iterations =    1
# norm(u) = 2.02040225, norm(v) = 0.79868353
# Courant number: 0.00500001
#
# Time = 1.26883717
# pressure solve iterations =    1
# norm(u) = 2.02075884, norm(v) = 0.79818399
# Courant number: 0.00500001
#
# Time = 1.27665859
# pressure solve iterations =    1
# norm(u) = 2.02109225, norm(v) = 0.79768381
# Courant number: 0.00500001
#
# Time = 1.28447435
# pressure solve iterations =    1
# norm(u) = 2.02140336, norm(v) = 0.79718329
# Courant number: 0.00500001
#
# Time = 1.29228461
# pressure solve iterations =    1
# norm(u) = 2.02169304, norm(v) = 0.79668271
# Courant number: 0.00500001
#
# Time = 1.30008953
# pressure solve iterations =    1
# norm(u) = 2.02196210, norm(v) = 0.79618233
# Courant number: 0.00500001
#
# Time = 1.30788925
# pressure solve iterations =    1
# norm(u) = 2.02221134, norm(v) = 0.79568240
# Courant number: 0.00500001
#
# Time = 1.31568393
# pressure solve iterations =    1
# norm(u) = 2.02244152, norm(v) = 0.79518317
# Courant number: 0.00500001
#
# Time = 1.32347370
# pressure solve iterations =    1
# norm(u) = 2.02265337, norm(v) = 0.79468487
# Courant number: 0.00500001
#
# Time = 1.33125869
# pressure solve iterations =    1
# norm(u) = 2.02284762, norm(v) = 0.79418770
# Courant number: 0.00500001
#
# Time = 1.33903905
# pressure solve iterations =    1
# norm(u) = 2.02302493, norm(v) = 0.79369188
# Courant number: 0.00500001
#
# Time = 1.34681489
# pressure solve iterations =    1
# norm(u) = 2.02318596, norm(v) = 0.79319759
# Courant number: 0.00500001
#
# Time = 1.35458635
# pressure solve iterations =    1
# norm(u) = 2.02333136, norm(v) = 0.79270503
# Courant number: 0.00500001
#
# Time = 1.36235355
# pressure solve iterations =    1
# norm(u) = 2.02346174, norm(v) = 0.79221435
# Courant number: 0.00500001
#
# Time = 1.37011660
# pressure solve iterations =    1
# norm(u) = 2.02357768, norm(v) = 0.79172574
# Courant number: 0.00500001
#
# Time = 1.37787562
# pressure solve iterations =    1
# norm(u) = 2.02367975, norm(v) = 0.79123934
# Courant number: 0.00500001
#
# Time = 1.38563072
# pressure solve iterations =    1
# norm(u) = 2.02376851, norm(v) = 0.79075530
# Courant number: 0.00500000
#
# Time = 1.39338200
# pressure solve iterations =    1
# norm(u) = 2.02384448, norm(v) = 0.79027376
# Courant number: 0.00500000
#
# Time = 1.40112958
# pressure solve iterations =    1
# norm(u) = 2.02390817, norm(v) = 0.78979484
# Courant number: 0.00500000
#
# Time = 1.40887351
# pressure solve iterations =    1
# norm(u) = 2.02396007, norm(v) = 0.78931868
# Courant number: 0.00500000
#
# Time = 1.41661389
# pressure solve iterations =    1
# norm(u) = 2.02400065, norm(v) = 0.78884538
# Courant number: 0.00500000
#
# Time = 1.42435080
# pressure solve iterations =    1
# norm(u) = 2.02403039, norm(v) = 0.78837506
# Courant number: 0.00500000
#
# Time = 1.43208435
# pressure solve iterations =    1
# norm(u) = 2.02404971, norm(v) = 0.78790781
# Courant number: 0.00500000
#
# Time = 1.43981463
# pressure solve iterations =    1
# norm(u) = 2.02405905, norm(v) = 0.78744374
# Courant number: 0.00500000
#
# Time = 1.44754172
# pressure solve iterations =    1
# norm(u) = 2.02405882, norm(v) = 0.78698293
# Courant number: 0.00500000
#
# Time = 1.45526571
# pressure solve iterations =    1
# norm(u) = 2.02404942, norm(v) = 0.78652546
# Courant number: 0.00500000
#
# Time = 1.46298669
# pressure solve iterations =    1
# norm(u) = 2.02403124, norm(v) = 0.78607142
# Courant number: 0.00500000
#
# Time = 1.47070472
# pressure solve iterations =    1
# norm(u) = 2.02400463, norm(v) = 0.78562087
# Courant number: 0.00500000
#
# Time = 1.47841991
# pressure solve iterations =    1
# norm(u) = 2.02396997, norm(v) = 0.78517388
# Courant number: 0.00500000
#
# Time = 1.48613231
# pressure solve iterations =    1
# norm(u) = 2.02392760, norm(v) = 0.78473052
# Courant number: 0.00500000
#
# Time = 1.49384201
# pressure solve iterations =    1
# norm(u) = 2.02387785, norm(v) = 0.78429083
# Courant number: 0.00500000
#
# Time = 1.50154908
# pressure solve iterations =    1
# norm(u) = 2.02382104, norm(v) = 0.78385488
# Courant number: 0.00500000
#
# Time = 1.50925359
# pressure solve iterations =    1
# norm(u) = 2.02375748, norm(v) = 0.78342271
# Courant number: 0.00500000
#
# Time = 1.51695560
# pressure solve iterations =    1
# norm(u) = 2.02368748, norm(v) = 0.78299437
# Courant number: 0.00500000
#
# Time = 1.52465520
# pressure solve iterations =    1
# norm(u) = 2.02361132, norm(v) = 0.78256989
# Courant number: 0.00500000
#
# Time = 1.53235244
# pressure solve iterations =    1
# norm(u) = 2.02352928, norm(v) = 0.78214931
# Courant number: 0.00500000
#
# Time = 1.54004738
# pressure solve iterations =    1
# norm(u) = 2.02344163, norm(v) = 0.78173267
# Courant number: 0.00500000
#
# Time = 1.54774009
# pressure solve iterations =    1
# norm(u) = 2.02334863, norm(v) = 0.78131999
# Courant number: 0.00500000
#
# Time = 1.55543064
# pressure solve iterations =    1
# norm(u) = 2.02325053, norm(v) = 0.78091130
# Courant number: 0.00500000
#
# Time = 1.56311907
# pressure solve iterations =    1
# norm(u) = 2.02314758, norm(v) = 0.78050663
# Courant number: 0.00500000
#
# Time = 1.57080544
# pressure solve iterations =    1
# norm(u) = 2.02304001, norm(v) = 0.78010599
# Courant number: 0.00500000
#
# Time = 1.57848982
# pressure solve iterations =    1
# norm(u) = 2.02292805, norm(v) = 0.77970940
# Courant number: 0.00500000
#
# Time = 1.58617226
# pressure solve iterations =    1
# norm(u) = 2.02281191, norm(v) = 0.77931687
# Courant number: 0.00500000
#
# Time = 1.59385281
# pressure solve iterations =    1
# norm(u) = 2.02269181, norm(v) = 0.77892843
# Courant number: 0.00500000
#
# Time = 1.60153151
# pressure solve iterations =    1
# norm(u) = 2.02256795, norm(v) = 0.77854406
# Courant number: 0.00500000
#
# Time = 1.60920843
# pressure solve iterations =    1
# norm(u) = 2.02244053, norm(v) = 0.77816379
# Courant number: 0.00500000
#
# Time = 1.61688362
# pressure solve iterations =    1
# norm(u) = 2.02230973, norm(v) = 0.77778761
# Courant number: 0.00500000
#
# Time = 1.62455711
# pressure solve iterations =    1
# norm(u) = 2.02217574, norm(v) = 0.77741554
# Courant number: 0.00500000
#
# Time = 1.63222896
# pressure solve iterations =    1
# norm(u) = 2.02203874, norm(v) = 0.77704756
# Courant number: 0.00500000
#
# Time = 1.63989921
# pressure solve iterations =    1
# norm(u) = 2.02189890, norm(v) = 0.77668368
# Courant number: 0.00500000
#
# Time = 1.64756791
# pressure solve iterations =    1
# norm(u) = 2.02175639, norm(v) = 0.77632390
# Courant number: 0.00500000
#
# Time = 1.65523509
# pressure solve iterations =    1
# norm(u) = 2.02161135, norm(v) = 0.77596820
# Courant number: 0.00500000
#
# Time = 1.66290081
# pressure solve iterations =    1
# norm(u) = 2.02146395, norm(v) = 0.77561659
# Courant number: 0.00500000
#
# Time = 1.67056511
# pressure solve iterations =    1
# norm(u) = 2.02131434, norm(v) = 0.77526904
# Courant number: 0.00500000
#
# Time = 1.67822801
# pressure solve iterations =    1
# norm(u) = 2.02116265, norm(v) = 0.77492556
# Courant number: 0.00500000
#
# Time = 1.68588957
# pressure solve iterations =    1
# norm(u) = 2.02100904, norm(v) = 0.77458614
# Courant number: 0.00500000
#
# Time = 1.69354982
# pressure solve iterations =    1
# norm(u) = 2.02085362, norm(v) = 0.77425074
# Courant number: 0.00500000
#
# Time = 1.70120880
# pressure solve iterations =    1
# norm(u) = 2.02069653, norm(v) = 0.77391938
# Courant number: 0.00500000
#
# Time = 1.70886654
# pressure solve iterations =    1
# norm(u) = 2.02053789, norm(v) = 0.77359202
# Courant number: 0.00500000
#
# Time = 1.71652309
# pressure solve iterations =    1
# norm(u) = 2.02037783, norm(v) = 0.77326865
# Courant number: 0.00500000
#
# Time = 1.72417846
# pressure solve iterations =    1
# norm(u) = 2.02021646, norm(v) = 0.77294925
# Courant number: 0.00500000
#
# Time = 1.73183271
# pressure solve iterations =    1
# norm(u) = 2.02005388, norm(v) = 0.77263381
# Courant number: 0.00500000
#
# Time = 1.73948585
# pressure solve iterations =    1
# norm(u) = 2.01989022, norm(v) = 0.77232231
# Courant number: 0.00500000
#
# Time = 1.74713793
# pressure solve iterations =    1
# norm(u) = 2.01972557, norm(v) = 0.77201471
# Courant number: 0.00500000
#
# Time = 1.75478897
# pressure solve iterations =    1
# norm(u) = 2.01956002, norm(v) = 0.77171101
# Courant number: 0.00500000
#
# Time = 1.76243900
# pressure solve iterations =    1
# norm(u) = 2.01939369, norm(v) = 0.77141117
# Courant number: 0.00500000
#
# Time = 1.77008806
# pressure solve iterations =    1
# norm(u) = 2.01922666, norm(v) = 0.77111518
# Courant number: 0.00500000
#
# Time = 1.77773617
# pressure solve iterations =    1
# norm(u) = 2.01905901, norm(v) = 0.77082301
# Courant number: 0.00500000
#
# Time = 1.78538336
# pressure solve iterations =    1
# norm(u) = 2.01889085, norm(v) = 0.77053464
# Courant number: 0.00500000
#
# Time = 1.79302966
# pressure solve iterations =    1
# norm(u) = 2.01872225, norm(v) = 0.77025004
# Courant number: 0.00500000
#
# Time = 1.80067509
# pressure solve iterations =    1
# norm(u) = 2.01855328, norm(v) = 0.76996918
# Courant number: 0.00500000
#
# Time = 1.80831968
# pressure solve iterations =    1
# norm(u) = 2.01838403, norm(v) = 0.76969203
# Courant number: 0.00500000
#
# Time = 1.81596346
# pressure solve iterations =    1
# norm(u) = 2.01821458, norm(v) = 0.76941858
# Courant number: 0.00500000
#
# Time = 1.82360645
# pressure solve iterations =    1
# norm(u) = 2.01804499, norm(v) = 0.76914879
# Courant number: 0.00500000
#
# Time = 1.83124868
# pressure solve iterations =    1
# norm(u) = 2.01787533, norm(v) = 0.76888263
# Courant number: 0.00500000
#
# Time = 1.83889016
# pressure solve iterations =    1
# norm(u) = 2.01770566, norm(v) = 0.76862007
# Courant number: 0.00500000
#
# Time = 1.84653093
# pressure solve iterations =    1
# norm(u) = 2.01753606, norm(v) = 0.76836110
# Courant number: 0.00500000
#
# Time = 1.85417100
# pressure solve iterations =    1
# norm(u) = 2.01736659, norm(v) = 0.76810566
# Courant number: 0.00500000
#
# Time = 1.86181040
# pressure solve iterations =    1
# norm(u) = 2.01719729, norm(v) = 0.76785374
# Courant number: 0.00500000
#
# Time = 1.86944914
# pressure solve iterations =    1
# norm(u) = 2.01702823, norm(v) = 0.76760531
# Courant number: 0.00500000
#
# Time = 1.87708726
# pressure solve iterations =    1
# norm(u) = 2.01685947, norm(v) = 0.76736034
# Courant number: 0.00500000
#
# Time = 1.88472476
# pressure solve iterations =    1
# norm(u) = 2.01669105, norm(v) = 0.76711878
# Courant number: 0.00500000
#
# Time = 1.89236167
# pressure solve iterations =    1
# norm(u) = 2.01652302, norm(v) = 0.76688062
# Courant number: 0.00500000
#
# Time = 1.89999800
# pressure solve iterations =    1
# norm(u) = 2.01635544, norm(v) = 0.76664582
# Courant number: 0.00500000
#
# Time = 1.90763378
# pressure solve iterations =    1
# norm(u) = 2.01618835, norm(v) = 0.76641436
# Courant number: 0.00500000
#
# Time = 1.91526903
# pressure solve iterations =    1
# norm(u) = 2.01602178, norm(v) = 0.76618619
# Courant number: 0.00500000
#
# Time = 1.92290376
# pressure solve iterations =    1
# norm(u) = 2.01585580, norm(v) = 0.76596129
# Courant number: 0.00500000
#
# Time = 1.93053798
# pressure solve iterations =    1
# norm(u) = 2.01569043, norm(v) = 0.76573962
# Courant number: 0.00500000
#
# Time = 1.93817173
# pressure solve iterations =    1
# norm(u) = 2.01552571, norm(v) = 0.76552116
# Courant number: 0.00500000
#
# Time = 1.94580500
# pressure solve iterations =    1
# norm(u) = 2.01536169, norm(v) = 0.76530586
# Courant number: 0.00500000
#
# Time = 1.95343783
# pressure solve iterations =    1
# norm(u) = 2.01519839, norm(v) = 0.76509371
# Courant number: 0.00500000
#
# Time = 1.96107021
# pressure solve iterations =    1
# norm(u) = 2.01503586, norm(v) = 0.76488466
# Courant number: 0.00500000
#
# Time = 1.96870218
# pressure solve iterations =    1
# norm(u) = 2.01487411, norm(v) = 0.76467869
# Courant number: 0.00500000
#
# Time = 1.97633375
# pressure solve iterations =    1
# norm(u) = 2.01471319, norm(v) = 0.76447576
# Courant number: 0.00500000
#
# Time = 1.98396492
# pressure solve iterations =    1
# norm(u) = 2.01455313, norm(v) = 0.76427584
# Courant number: 0.00500000
#
# Time = 1.99159571
# pressure solve iterations =    1
# norm(u) = 2.01439395, norm(v) = 0.76407890
# Courant number: 0.00500000
#
# Time = 1.99922614
# pressure solve iterations =    1
# norm(u) = 2.01423567, norm(v) = 0.76388490
# Courant number: 0.00500000
#
# Time = 2.00685622
# pressure solve iterations =    1
# norm(u) = 2.01407833, norm(v) = 0.76369381
# Courant number: 0.00500000
#
# Time = 2.01448597
# pressure solve iterations =    1
# norm(u) = 2.01392195, norm(v) = 0.76350561
# Courant number: 0.00500000
#
# Time = 2.02211539
# pressure solve iterations =    1
# norm(u) = 2.01376654, norm(v) = 0.76332025
# Courant number: 0.00500000
#
# Time = 2.02974449
# pressure solve iterations =    1
# norm(u) = 2.01361214, norm(v) = 0.76313772
# Courant number: 0.00500000
#
# Time = 2.03737330
# pressure solve iterations =    1
# norm(u) = 2.01345877, norm(v) = 0.76295796
# Courant number: 0.00500000
#
# Time = 2.04500182
# pressure solve iterations =    1
# norm(u) = 2.01330643, norm(v) = 0.76278096
# Courant number: 0.00500000
#
# Time = 2.05263006
# pressure solve iterations =    1
# norm(u) = 2.01315516, norm(v) = 0.76260668
# Courant number: 0.00500000
#
# Time = 2.06025804
# pressure solve iterations =    1
# norm(u) = 2.01300496, norm(v) = 0.76243509
# Courant number: 0.00500000
#
# Time = 2.06788576
# pressure solve iterations =    1
# norm(u) = 2.01285586, norm(v) = 0.76226616
# Courant number: 0.00500000
#
# Time = 2.07551323
# pressure solve iterations =    1
# norm(u) = 2.01270787, norm(v) = 0.76209985
# Courant number: 0.00500000
#
# Time = 2.08314047
# pressure solve iterations =    1
# norm(u) = 2.01256100, norm(v) = 0.76193614
# Courant number: 0.00500000
#
# Time = 2.09076749
# pressure solve iterations =    1
# norm(u) = 2.01241527, norm(v) = 0.76177499
# Courant number: 0.00500000
#
# Time = 2.09839429
# pressure solve iterations =    1
# norm(u) = 2.01227069, norm(v) = 0.76161638
# Courant number: 0.00500000
#
# Time = 2.10602089
# pressure solve iterations =    1
# norm(u) = 2.01212728, norm(v) = 0.76146026
# Courant number: 0.00500000
#
# Time = 2.11364729
# pressure solve iterations =    1
# norm(u) = 2.01198503, norm(v) = 0.76130662
# Courant number: 0.00500000
#
# Time = 2.12127350
# pressure solve iterations =    1
# norm(u) = 2.01184397, norm(v) = 0.76115542
# Courant number: 0.00500000
#
# Time = 2.12889953
# pressure solve iterations =    1
# norm(u) = 2.01170410, norm(v) = 0.76100663
# Courant number: 0.00500000
#
# Time = 2.13652540
# pressure solve iterations =    1
# norm(u) = 2.01156543, norm(v) = 0.76086022
# Courant number: 0.00500000
#
# Time = 2.14415110
# pressure solve iterations =    1
# norm(u) = 2.01142797, norm(v) = 0.76071616
# Courant number: 0.00500000
# Steady state reached at time:  2.1449060317007858
# Time taken by calculation =  116.0293779373169

# %%
# set up figure
fig = plt.figure(figsize=(21, 7))
ax1 = fig.add_subplot(121)
cont = ax1.contourf(X,Y,p, cmap=cm.coolwarm)
fig.colorbar(cont)
# don't plot at every gird point - every 5th
ax1.quiver(X[::5,::5],Y[::5,::5],u[::5,::5],v[::5,::5])
ax1.set_xlim(-0.0001, 0.01)
ax1.set_ylim(-0.0001, 0.0051)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - pressure and velocity vectors', fontsize=16)

ax1 = fig.add_subplot(122)
cont = ax1.contourf(X,Y,np.sqrt(u*u+v*v), cmap=cm.coolwarm)
fig.colorbar(cont)
ax1.set_xlim(-0.0001, 0.01)
ax1.set_ylim(-0.0001, 0.0051)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - speed', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pressure driven problem - speed')

# %%
flow_in = np.average(u[0,:])*Ly
flow_out = np.average(v[:,-1])*Lx

print('flow in: ',flow_in)
print('flow out: ',flow_out)
# Out:
# flow in:  0.0
# flow out:  0.0

# %% [markdown]
# # b)Finite Difference Approximation for Advection-Diffusion Equation
#
# Given the advection-diffusion equation:
#
# $$\frac{\partial T}{\partial t} = -\vec{v} \cdot \nabla T + k \nabla^2 T $$
#
# where:
#
# - ( T ) is the temperature,
# - ( $\vec{v}$ ) is the velocity field,
# - ( k ) is the diffusion coefficient.
#
# We will derive a finite difference approximation for time-stepping this equation.
#
# ## Temporal Discretization
#
# We use the Forward Euler method for the time derivative:
#
# $$\frac{\partial T}{\partial t} \approx \frac{T^{n+1}_{i,j} - T^n_{i,j}}{\Delta t}$$
#
# where $T^n_{i,j}$ is the temperature at the current time step and grid point(i, j), and $T^{n+1}_{i,j}$ is the temperature at the next time step at the same grid point.
#
# ## Spatial Discretization
#
# ### Advection Term
#
# Using an upwind scheme for the advection term:
#
# - If \( v<sub>x</sub> > 0 \):
#
# $$-\vec{v} \cdot \nabla T \approx -v_x \frac{T^n_{i,j} - T^n_{i-1,j}}{\Delta x}$$
#
# - If \( v<sub>x</sub> <= 0 \):
#
# $$-\vec{v} \cdot \nabla T \approx -v_x \frac{T^n_{i+1,j} - T^n_{i,j}}{\Delta x}$$
#
# - If \( v<sub>y</sub> > 0 \):
#
# $$-\vec{v} \cdot \nabla T \approx -v_y \frac{T^n_{i,j} - T^n_{i,j-1}}{\Delta y}$$
#
# - If \( v<sub>y</sub> <= 0 \):
#
# $$-\vec{v} \cdot \nabla T \approx -v_y \frac{T^n_{i,j+1} - T^n_{i,j}}{\Delta y}$$
#
# ### Diffusion Term
#
# Using a central difference scheme for the Laplacian:
#
# $$k \nabla^2 T \approx k \left[ \frac{T^n_{i+1,j} - 2T^n_{i,j} + T^n_{i-1,j}}{\Delta x^2} + \frac{T^n_{i,j+1} - 2T^n_{i,j} + T^n_{i,j-1}}{\Delta y^2} \right]$$
#
# ## Combined Finite Difference Equation
#
# The finite difference equation for the temperature update becomes:
#
# $$T^{n+1}_{i,j} = T^n_{i,j} + \Delta t \left[ -v_x \left( \frac{T^n_{_(upwind),_(upwind)} - T^n_{_(upwind),_(upwind)}}{\Delta x} \right) - v_y \left( \frac{T^n_{_(upwind),_(upwind)} - T^n_{_(upwind),_(upwind)}}{\Delta y} \right) + k \left( \frac{T^n_{i+1,j} - 2T^n_{i,j} + T^n_{i-1,j}}{\Delta x^2} + \frac{T^n_{i,j+1} - 2T^n_{i,j} + T^n_{i,j-1}}{\Delta y^2} \right) \right]$$
#
# This equation can be used to step the temperature field forward in time. Note that this is for positive velocity components; for negative velocities, the indices in the advection term should be adjusted to maintain the upwind scheme.
#
# ## Stability Considerations
#
# The stability of the scheme is governed by the Courant-Friedrichs-Lewy (CFL) condition for the advection terms and the stability condition for diffusion, which will dictate the maximum allowable time step ( $\Delta t$ ).

# %% [markdown]
# # c) Advection-diffusion implement into NS-solver
# First define the temperature updation code we derived above

# %%
def update_temperature(T, u, v, k, dt, dx, dy, rho, Cp=4184):
    """
    Update the temperature field based on the advection-diffusion equation.
    
    Parameters:
    T    -- the current temperature field
    u, v -- the velocity components of the fluid
    k    -- the thermal diffusivity
    dt   -- time step
    dx, dy -- grid spacing in the x and y directions
    rho  -- density of the fluid
    Cp   -- specific heat capacity of the fluid

    Returns:
    T_new -- the updated temperature field
    """
    # Create a new temperature field
    T_new = np.copy(T)
    
    # Constants for the Peclet number
    Pe_x = rho * Cp * u * dx / k
    Pe_y = rho * Cp * v * dy / k
        
    # Advection terms
    # Create conditions for the upwind scheme
    conditions_x = [u[1:-1, 1:-1] >= 0, u[1:-1, 1:-1] < 0]
    conditions_y = [v[1:-1, 1:-1] >= 0, v[1:-1, 1:-1] < 0]

    # Calculate the advection terms using np.select and np.roll
    adv_x = np.select(conditions_x, [
        u[1:-1, 1:-1] * (T[1:-1, 1:-1] - np.roll(T, 1, axis=0)[1:-1, 1:-1]) / dx,
        u[1:-1, 1:-1] * (np.roll(T, -1, axis=0)[1:-1, 1:-1] - T[1:-1, 1:-1]) / dx
    ])

    adv_y = np.select(conditions_y, [
        v[1:-1, 1:-1] * (T[1:-1, 1:-1] - np.roll(T, 1, axis=1)[1:-1, 1:-1]) / dy,
        v[1:-1, 1:-1] * (np.roll(T, -1, axis=1)[1:-1, 1:-1] - T[1:-1, 1:-1]) / dy
    ])

    # Diffusion terms
    diff_x = k * (np.roll(T, -1, axis=0)[1:-1, 1:-1] - 2 * T[1:-1, 1:-1] + np.roll(T, 1, axis=0)[1:-1, 1:-1]) / dx**2
    diff_y = k * (np.roll(T, -1, axis=1)[1:-1, 1:-1] - 2 * T[1:-1, 1:-1] + np.roll(T, 1, axis=1)[1:-1, 1:-1]) / dy**2

    # Update the temperature field
    T_new[1:-1, 1:-1] = T[1:-1, 1:-1] - dt * (adv_x + adv_y) + dt * (diff_x + diff_y)

    # Boundary conditions
    T_new[0,:] = 20  # Inlet temperature in degrees Celsius

    T_new[:-(imax-imax//2) + 1, -1] = 100 #Top wall
    T_new[(imax-imax//2):, -1] = T_new[(imax-imax//2):, -2]

    T_new[-1,:] = 100  # right boundary temperature

    T_new[1:-1,0] = 100 # bottom boundary temperature

    
    return T_new

# %% [markdown]
# ### Modified NS-solver with temp updation
# I added the temp updation function into the NS_solver function, as well as adding the third steady-state condition. Also at the $\Delta t$ selection, add a loop break and tell user if the dt is too high and reduce the courant number, as well as the required minimum $\Delta t$.

# %%
def solve_NS_with_Temp_update(u, v, p, T, k, rho, nu, courant, dt_min, t_end, dx, dy, rtol = 1.e-5, logs = False, outint = 100):
    """ Solve the incompressible Navier-Stokes equations
    using a lot of the numerical choices and approaches we've seen
    earlier in this lecture.
    """
    t = 0
    
    u_old = u.copy()
    v_old = v.copy()
    T_old = T.copy()
    p_RHS = np.zeros_like(X)
    
    time_it = 0 
    steady_state_reached = False
    while t < t_end and not steady_state_reached:
        time_it+=1
        #set dt based on courant number
        vel_max = np.max(np.sqrt(u**2+v**2))
        if vel_max>0.0:
            dt = min(courant*min(dx,dy)/vel_max,dt_min)
        else:
            dt = dt_min

        if(not dt < dx**2/(2*k)/10):
            print("dt is too high, please reduce courant number, minimum dt is: ", dx**2/(2*k)/10)
            break
            
        t += dt
        if logs and time_it%outint == 0: 
            print('\nTime = {:.8f}'.format(t))
            
        # calculate intermediate velocities
        u, v = calculate_intermediate_velocity(nu, u, v, u_old, v_old, dt, dx, dy)
        # PPM
        # calculate RHS for the pressure Poisson problem
        p_RHS = calculate_ppm_RHS_central(rho, u, v, p_RHS, dt, dx, dy)
        # compute pressure - note that we use the previous p as an initial guess to the solution
        p = pressure_poisson_jacobi(p, dx, dy, p_RHS, 1.e-5, logs = (logs and time_it%outint == 0))
        # project velocity
        u, v = project_velocity(rho, u, v, dt, dx, dy, p)
        
        T = update_temperature(T, u, v, k, dt, dx, dy, rho, Cp=1)

        if logs and time_it%outint == 0:
            print('norm(u) = {0:.8f}, norm(v) = {1:.8f}'.format(sl.norm(u),sl.norm(v)))
            print('Courant number: {0:.8f}'.format(np.max(np.sqrt(u**2+v**2)) * dt / min(dx,dy)))
                
        #swap pointers without copying data
        temp = u_old
        u_old = u
        u = temp
        temp = v_old
        v_old = v
        v = temp
        temp = T_old
        T_old = T
        T = temp
        
        # Check if the system has reached a steady state
        steady_state_reached = has_reached_steady_state(u_old, u) and \
                       has_reached_steady_state(v_old, v) and \
                       has_reached_steady_state(T_old, T,tolerance=1e-4)
        if(steady_state_reached):
            print("Steady state reached at time: ", t)

    return u, v, p, T

# %% [markdown]
# ### Redefine the parameters and boundary conditions, and initialize the simulation

# %%
# redefine physical parameters
rho = 1000
nu = 0.001/1000.
k = 5e-6
rho = 1000
nu = 0.001/1000.

# define spatial mesh
# Size of rectangular domain
Lx = 0.01
Ly = 0.005
P_max = 0.5

# Number of grid points in each direction, including boundary nodes
Nx = 101
Ny = 76

# hence the mesh spacing
dx = Lx/(Nx-1)
dy = Ly/(Ny-1)

# read the docs to see the ordering that mgrid gives us
X, Y = np.mgrid[0:Nx:1, 0:Ny:1]
X = dx*X
Y = dy*Y
# the following is an alternative to the three lines above
#X, Y = np.mgrid[0: Lx + 1e-10: dx, 0: Ly + 1e-10: dy]
# but without the need to add a "small" increement to ensure
# the Lx and Ly end points are included

# initialise independent variables
u = np.zeros_like(X)
v = np.zeros_like(X)
p = np.zeros_like(X)
T = np.zeros_like(X)

# Apply Dirichlet BCs to u and v - the code below doesn't touch 
# these so we can do this once outside the time loop
u[:, -1] = 0
u[:, 0] = 0
u[0, :] = 0
u[-1, :] = 0
v[:, -1] = 0
v[:, 0] = 0
v[0, :] = 0
v[-1, :] = 0
imax = len(u)
jmax = np.size(u)//imax
p[0,] = P_max
p[imax//2:, -1] = 0.0


# Boundary conditions
T[0,:] = 20  # Inlet temperature in degrees Celsius
T[len(T)//2:,-1] = 0.0  #Top boundary
T[:len(T)//2,-1] = 100
T[-1,:] = 100  # Right boundary temperature 
T[1:-1,0] = 100 # bottom boundary temperature

courant = 0.005
dt_min = 1.e-5

t_end = 10
import time
start = time.time()
u, v, p ,T= solve_NS_with_Temp_update(u, v, p, T, k, rho, nu, courant, dt_min, t_end, dx, dy, rtol = 1.e-6, logs = True, outint = 1000)
end = time.time()
print('Time taken by calculation = ', end - start)
# Out:
# Time = 0.01000000
# pressure solve iterations =    1
# norm(u) = 0.04355163, norm(v) = 0.02146672
# Courant number: 0.00031737
#
# Time = 0.02000000
# pressure solve iterations =    1
# norm(u) = 0.08579010, norm(v) = 0.04224900
# Courant number: 0.00053943
#
# Time = 0.03000000
# pressure solve iterations =    1
# norm(u) = 0.12715492, norm(v) = 0.06251785
# Courant number: 0.00071041
#
# Time = 0.04000000
# pressure solve iterations =    1
# norm(u) = 0.16781028, norm(v) = 0.08232243
# Courant number: 0.00086329
#
# Time = 0.05000000
# pressure solve iterations =    1
# norm(u) = 0.20785160, norm(v) = 0.10169569
# Courant number: 0.00100639
#
# Time = 0.06000000
# pressure solve iterations =    1
# norm(u) = 0.24734392, norm(v) = 0.12066404
# Courant number: 0.00113938
#
# Time = 0.07000000
# pressure solve iterations =    1
# norm(u) = 0.28633506, norm(v) = 0.13925104
# Courant number: 0.00125966
#
# Time = 0.08000000
# pressure solve iterations =    1
# norm(u) = 0.32486160, norm(v) = 0.15747863
# Courant number: 0.00137395
#
# Time = 0.09000000
# pressure solve iterations =    1
# norm(u) = 0.36295219, norm(v) = 0.17536756
# Courant number: 0.00148615
#
# Time = 0.10000000
# pressure solve iterations =    1
# norm(u) = 0.40062944, norm(v) = 0.19293731
# Courant number: 0.00159531
#
# Time = 0.11000000
# pressure solve iterations =    1
# norm(u) = 0.43791114, norm(v) = 0.21020606
# Courant number: 0.00169948
#
# Time = 0.12000000
# pressure solve iterations =    1
# norm(u) = 0.47481082, norm(v) = 0.22719110
# Courant number: 0.00180079
#
# Time = 0.13000000
# pressure solve iterations =    1
# norm(u) = 0.51133878, norm(v) = 0.24390763
# Courant number: 0.00189683
#
# Time = 0.14000000
# pressure solve iterations =    1
# norm(u) = 0.54750212, norm(v) = 0.26036947
# Courant number: 0.00198825
#
# Time = 0.15000000
# pressure solve iterations =    1
# norm(u) = 0.58330516, norm(v) = 0.27658873
# Courant number: 0.00207896
#
# Time = 0.16000000
# pressure solve iterations =    1
# norm(u) = 0.61874971, norm(v) = 0.29257573
# Courant number: 0.00216831
#
# Time = 0.17000000
# pressure solve iterations =    1
# norm(u) = 0.65383523, norm(v) = 0.30833897
# Courant number: 0.00225434
#
# Time = 0.18000000
# pressure solve iterations =    1
# norm(u) = 0.68855908, norm(v) = 0.32388510
# Courant number: 0.00233731
#
# Time = 0.19000000
# pressure solve iterations =    1
# norm(u) = 0.72291671, norm(v) = 0.33921893
# Courant number: 0.00241785
#
# Time = 0.20000000
# pressure solve iterations =    1
# norm(u) = 0.75690181, norm(v) = 0.35434353
# Courant number: 0.00249918
#
# Time = 0.21000000
# pressure solve iterations =    1
# norm(u) = 0.79050654, norm(v) = 0.36926026
# Courant number: 0.00257812
#
# Time = 0.22000000
# pressure solve iterations =    2
# norm(u) = 0.82372174, norm(v) = 0.38396890
# Courant number: 0.00265481
#
# Time = 0.23000000
# pressure solve iterations =    2
# norm(u) = 0.85653717, norm(v) = 0.39846781
# Courant number: 0.00273069
#
# Time = 0.24000000
# pressure solve iterations =    1
# norm(u) = 0.88894171, norm(v) = 0.41275406
# Courant number: 0.00280665
#
# Time = 0.25000000
# pressure solve iterations =    2
# norm(u) = 0.92092361, norm(v) = 0.42682365
# Courant number: 0.00288189
#
# Time = 0.26000000
# pressure solve iterations =    2
# norm(u) = 0.95247077, norm(v) = 0.44067164
# Courant number: 0.00295528
#
# Time = 0.27000000
# pressure solve iterations =    2
# norm(u) = 0.98357090, norm(v) = 0.45429238
# Courant number: 0.00302692
#
# Time = 0.28000000
# pressure solve iterations =    2
# norm(u) = 1.01421183, norm(v) = 0.46767969
# Courant number: 0.00309687
#
# Time = 0.29000000
# pressure solve iterations =    1
# norm(u) = 1.04438164, norm(v) = 0.48082704
# Courant number: 0.00316631
#
# Time = 0.30000000
# pressure solve iterations =    2
# norm(u) = 1.07406891, norm(v) = 0.49372773
# Courant number: 0.00323586
#
# Time = 0.31000000
# pressure solve iterations =    1
# norm(u) = 1.10326280, norm(v) = 0.50637507
# Courant number: 0.00330391
#
# Time = 0.32000000
# pressure solve iterations =    2
# norm(u) = 1.13195326, norm(v) = 0.51876250
# Courant number: 0.00337049
#
# Time = 0.33000000
# pressure solve iterations =    2
# norm(u) = 1.16013106, norm(v) = 0.53088373
# Courant number: 0.00343610
#
# Time = 0.34000000
# pressure solve iterations =    2
# norm(u) = 1.18778789, norm(v) = 0.54273288
# Courant number: 0.00350181
#
# Time = 0.35000000
# pressure solve iterations =    2
# norm(u) = 1.21491637, norm(v) = 0.55430452
# Courant number: 0.00356722
#
# Time = 0.36000000
# pressure solve iterations =    2
# norm(u) = 1.24151008, norm(v) = 0.56559379
# Courant number: 0.00363213
#
# Time = 0.37000000
# pressure solve iterations =    2
# norm(u) = 1.26756354, norm(v) = 0.57659645
# Courant number: 0.00369574
#
# Time = 0.38000000
# pressure solve iterations =    2
# norm(u) = 1.29307214, norm(v) = 0.58730890
# Courant number: 0.00375806
#
# Time = 0.39000000
# pressure solve iterations =    2
# norm(u) = 1.31803218, norm(v) = 0.59772820
# Courant number: 0.00381914
#
# Time = 0.40000000
# pressure solve iterations =    2
# norm(u) = 1.34244075, norm(v) = 0.60785214
# Courant number: 0.00387960
#
# Time = 0.41000000
# pressure solve iterations =    1
# norm(u) = 1.36629569, norm(v) = 0.61767917
# Courant number: 0.00394002
#
# Time = 0.42000000
# pressure solve iterations =    1
# norm(u) = 1.38959559, norm(v) = 0.62720844
# Courant number: 0.00399926
#
# Time = 0.43000000
# pressure solve iterations =    2
# norm(u) = 1.41233966, norm(v) = 0.63643973
# Courant number: 0.00405901
#
# Time = 0.44000000
# pressure solve iterations =    1
# norm(u) = 1.43452780, norm(v) = 0.64537353
# Courant number: 0.00411761
#
# Time = 0.45000000
# pressure solve iterations =    2
# norm(u) = 1.45616048, norm(v) = 0.65401090
# Courant number: 0.00417509
#
# Time = 0.46000000
# pressure solve iterations =    1
# norm(u) = 1.47723880, norm(v) = 0.66235349
# Courant number: 0.00423145
#
# Time = 0.47000000
# pressure solve iterations =    2
# norm(u) = 1.49776444, norm(v) = 0.67040354
# Courant number: 0.00428732
#
# Time = 0.48000000
# pressure solve iterations =    1
# norm(u) = 1.51773966, norm(v) = 0.67816380
# Courant number: 0.00434301
#
# Time = 0.49000000
# pressure solve iterations =    1
# norm(u) = 1.53716732, norm(v) = 0.68563750
# Courant number: 0.00439803
#
# Time = 0.50000000
# pressure solve iterations =    1
# norm(u) = 1.55605091, norm(v) = 0.69282831
# Courant number: 0.00445337
#
# Time = 0.51000000
# pressure solve iterations =    1
# norm(u) = 1.57439448, norm(v) = 0.69974034
# Courant number: 0.00450827
#
# Time = 0.52000000
# pressure solve iterations =    1
# norm(u) = 1.59220271, norm(v) = 0.70637805
# Courant number: 0.00456283
#
# Time = 0.53000000
# pressure solve iterations =    1
# norm(u) = 1.60948087, norm(v) = 0.71274624
# Courant number: 0.00461623
#
# Time = 0.54000000
# pressure solve iterations =    1
# norm(u) = 1.62623483, norm(v) = 0.71884995
# Courant number: 0.00466850
#
# Time = 0.55000000
# pressure solve iterations =    1
# norm(u) = 1.64247101, norm(v) = 0.72469457
# Courant number: 0.00472035
#
# Time = 0.56000000
# pressure solve iterations =    1
# norm(u) = 1.65819633, norm(v) = 0.73028572
# Courant number: 0.00477162
#
# Time = 0.57000000
# pressure solve iterations =    1
# norm(u) = 1.67341829, norm(v) = 0.73562902
# Courant number: 0.00482173
#
# Time = 0.58000000
# pressure solve iterations =    1
# norm(u) = 1.68814490, norm(v) = 0.74073022
# Courant number: 0.00487068
#
# Time = 0.59000000
# pressure solve iterations =    1
# norm(u) = 1.70238455, norm(v) = 0.74559528
# Courant number: 0.00491847
#
# Time = 0.60000000
# pressure solve iterations =    1
# norm(u) = 1.71614601, norm(v) = 0.75023020
# Courant number: 0.00496599
#
# Time = 0.60999662
# pressure solve iterations =    1
# norm(u) = 1.72943362, norm(v) = 0.75463934
# Courant number: 0.00500009
#
# Time = 0.61992688
# pressure solve iterations =    1
# norm(u) = 1.74217200, norm(v) = 0.75879958
# Courant number: 0.00500009
#
# Time = 0.62977057
# pressure solve iterations =    1
# norm(u) = 1.75435562, norm(v) = 0.76271315
# Courant number: 0.00500008
#
# Time = 0.63953207
# pressure solve iterations =    1
# norm(u) = 1.76601271, norm(v) = 0.76639431
# Courant number: 0.00500008
#
# Time = 0.64921501
# pressure solve iterations =    1
# norm(u) = 1.77716887, norm(v) = 0.76985592
# Courant number: 0.00500008
#
# Time = 0.65882211
# pressure solve iterations =    1
# norm(u) = 1.78784724, norm(v) = 0.77310960
# Courant number: 0.00500008
#
# Time = 0.66835696
# pressure solve iterations =    1
# norm(u) = 1.79807077, norm(v) = 0.77616661
# Courant number: 0.00500007
#
# Time = 0.67782257
# pressure solve iterations =    1
# norm(u) = 1.80786060, norm(v) = 0.77903732
# Courant number: 0.00500007
#
# Time = 0.68722139
# pressure solve iterations =    1
# norm(u) = 1.81723622, norm(v) = 0.78173129
# Courant number: 0.00500007
#
# Time = 0.69655646
# pressure solve iterations =    1
# norm(u) = 1.82621685, norm(v) = 0.78425774
# Courant number: 0.00500007
#
# Time = 0.70583065
# pressure solve iterations =    1
# norm(u) = 1.83482061, norm(v) = 0.78662533
# Courant number: 0.00500006
#
# Time = 0.71504667
# pressure solve iterations =    1
# norm(u) = 1.84306456, norm(v) = 0.78884219
# Courant number: 0.00500006
#
# Time = 0.72420708
# pressure solve iterations =    1
# norm(u) = 1.85096482, norm(v) = 0.79091597
# Courant number: 0.00500006
#
# Time = 0.73331428
# pressure solve iterations =    1
# norm(u) = 1.85853663, norm(v) = 0.79285384
# Courant number: 0.00500006
#
# Time = 0.74237053
# pressure solve iterations =    1
# norm(u) = 1.86579441, norm(v) = 0.79466260
# Courant number: 0.00500005
#
# Time = 0.75137797
# pressure solve iterations =    1
# norm(u) = 1.87275182, norm(v) = 0.79634866
# Courant number: 0.00500005
#
# Time = 0.76033864
# pressure solve iterations =    1
# norm(u) = 1.87942184, norm(v) = 0.79791808
# Courant number: 0.00500005
#
# Time = 0.76925446
# pressure solve iterations =    1
# norm(u) = 1.88581678, norm(v) = 0.79937660
# Courant number: 0.00500005
#
# Time = 0.77812725
# pressure solve iterations =    1
# norm(u) = 1.89194834, norm(v) = 0.80072965
# Courant number: 0.00500005
#
# Time = 0.78695873
# pressure solve iterations =    1
# norm(u) = 1.89782764, norm(v) = 0.80198239
# Courant number: 0.00500005
#
# Time = 0.79575054
# pressure solve iterations =    1
# norm(u) = 1.90346529, norm(v) = 0.80313971
# Courant number: 0.00500004
#
# Time = 0.80450408
# pressure solve iterations =    1
# norm(u) = 1.90887124, norm(v) = 0.80420622
# Courant number: 0.00500004
#
# Time = 0.81322056
# pressure solve iterations =    1
# norm(u) = 1.91405496, norm(v) = 0.80518631
# Courant number: 0.00500004
#
# Time = 0.82190140
# pressure solve iterations =    1
# norm(u) = 1.91902566, norm(v) = 0.80608419
# Courant number: 0.00500004
#
# Time = 0.83054799
# pressure solve iterations =    1
# norm(u) = 1.92379215, norm(v) = 0.80690387
# Courant number: 0.00500004
#
# Time = 0.83916163
# pressure solve iterations =    1
# norm(u) = 1.92836282, norm(v) = 0.80764919
# Courant number: 0.00500004
#
# Time = 0.84774355
# pressure solve iterations =    1
# norm(u) = 1.93274568, norm(v) = 0.80832376
# Courant number: 0.00500004
#
# Time = 0.85629494
# pressure solve iterations =    1
# norm(u) = 1.93694837, norm(v) = 0.80893105
# Courant number: 0.00500003
#
# Time = 0.86481693
# pressure solve iterations =    1
# norm(u) = 1.94097821, norm(v) = 0.80947435
# Courant number: 0.00500003
#
# Time = 0.87331060
# pressure solve iterations =    1
# norm(u) = 1.94484217, norm(v) = 0.80995681
# Courant number: 0.00500003
#
# Time = 0.88177699
# pressure solve iterations =    1
# norm(u) = 1.94854693, norm(v) = 0.81038142
# Courant number: 0.00500003
#
# Time = 0.89021706
# pressure solve iterations =    1
# norm(u) = 1.95209887, norm(v) = 0.81075103
# Courant number: 0.00500003
#
# Time = 0.89863178
# pressure solve iterations =    1
# norm(u) = 1.95550410, norm(v) = 0.81106837
# Courant number: 0.00500003
#
# Time = 0.90702203
# pressure solve iterations =    1
# norm(u) = 1.95876845, norm(v) = 0.81133604
# Courant number: 0.00500003
#
# Time = 0.91538868
# pressure solve iterations =    1
# norm(u) = 1.96189753, norm(v) = 0.81155652
# Courant number: 0.00500003
#
# Time = 0.92373256
# pressure solve iterations =    1
# norm(u) = 1.96489668, norm(v) = 0.81173219
# Courant number: 0.00500003
#
# Time = 0.93205446
# pressure solve iterations =    1
# norm(u) = 1.96777104, norm(v) = 0.81186531
# Courant number: 0.00500003
#
# Time = 0.94035513
# pressure solve iterations =    1
# norm(u) = 1.97052553, norm(v) = 0.81195804
# Courant number: 0.00500002
#
# Time = 0.94863531
# pressure solve iterations =    1
# norm(u) = 1.97316484, norm(v) = 0.81201245
# Courant number: 0.00500002
#
# Time = 0.95689569
# pressure solve iterations =    1
# norm(u) = 1.97569350, norm(v) = 0.81203051
# Courant number: 0.00500002
#
# Time = 0.96513694
# pressure solve iterations =    1
# norm(u) = 1.97811583, norm(v) = 0.81201412
# Courant number: 0.00500002
#
# Time = 0.97335971
# pressure solve iterations =    1
# norm(u) = 1.98043597, norm(v) = 0.81196506
# Courant number: 0.00500002
#
# Time = 0.98156460
# pressure solve iterations =    1
# norm(u) = 1.98265791, norm(v) = 0.81188507
# Courant number: 0.00500002
#
# Time = 0.98975222
# pressure solve iterations =    1
# norm(u) = 1.98478546, norm(v) = 0.81177579
# Courant number: 0.00500002
#
# Time = 0.99792314
# pressure solve iterations =    1
# norm(u) = 1.98682228, norm(v) = 0.81163880
# Courant number: 0.00500002
#
# Time = 1.00607789
# pressure solve iterations =    1
# norm(u) = 1.98877188, norm(v) = 0.81147561
# Courant number: 0.00500002
#
# Time = 1.01421702
# pressure solve iterations =    1
# norm(u) = 1.99063763, norm(v) = 0.81128765
# Courant number: 0.00500002
#
# Time = 1.02234102
# pressure solve iterations =    1
# norm(u) = 1.99242276, norm(v) = 0.81107630
# Courant number: 0.00500002
#
# Time = 1.03045038
# pressure solve iterations =    1
# norm(u) = 1.99413039, norm(v) = 0.81084287
# Courant number: 0.00500002
#
# Time = 1.03854557
# pressure solve iterations =    1
# norm(u) = 1.99576347, norm(v) = 0.81058864
# Courant number: 0.00500002
#
# Time = 1.04662705
# pressure solve iterations =    1
# norm(u) = 1.99732489, norm(v) = 0.81031478
# Courant number: 0.00500002
#
# Time = 1.05469525
# pressure solve iterations =    1
# norm(u) = 1.99881738, norm(v) = 0.81002247
# Courant number: 0.00500002
#
# Time = 1.06275059
# pressure solve iterations =    1
# norm(u) = 2.00024359, norm(v) = 0.80971279
# Courant number: 0.00500002
#
# Time = 1.07079347
# pressure solve iterations =    1
# norm(u) = 2.00160604, norm(v) = 0.80938681
# Courant number: 0.00500002
#
# Time = 1.07882428
# pressure solve iterations =    1
# norm(u) = 2.00290717, norm(v) = 0.80904551
# Courant number: 0.00500001
#
# Time = 1.08684340
# pressure solve iterations =    1
# norm(u) = 2.00414931, norm(v) = 0.80868987
# Courant number: 0.00500001
#
# Time = 1.09485119
# pressure solve iterations =    1
# norm(u) = 2.00533473, norm(v) = 0.80832080
# Courant number: 0.00500001
#
# Time = 1.10284800
# pressure solve iterations =    1
# norm(u) = 2.00646557, norm(v) = 0.80793919
# Courant number: 0.00500001
#
# Time = 1.11083417
# pressure solve iterations =    1
# norm(u) = 2.00754390, norm(v) = 0.80754586
# Courant number: 0.00500001
#
# Time = 1.11881002
# pressure solve iterations =    1
# norm(u) = 2.00857173, norm(v) = 0.80714162
# Courant number: 0.00500001
#
# Time = 1.12677587
# pressure solve iterations =    1
# norm(u) = 2.00955097, norm(v) = 0.80672723
# Courant number: 0.00500001
#
# Time = 1.13473201
# pressure solve iterations =    1
# norm(u) = 2.01048346, norm(v) = 0.80630344
# Courant number: 0.00500001
#
# Time = 1.14267875
# pressure solve iterations =    1
# norm(u) = 2.01137097, norm(v) = 0.80587093
# Courant number: 0.00500001
#
# Time = 1.15061637
# pressure solve iterations =    1
# norm(u) = 2.01221521, norm(v) = 0.80543038
# Courant number: 0.00500001
#
# Time = 1.15854513
# pressure solve iterations =    1
# norm(u) = 2.01301782, norm(v) = 0.80498242
# Courant number: 0.00500001
#
# Time = 1.16646530
# pressure solve iterations =    1
# norm(u) = 2.01378036, norm(v) = 0.80452766
# Courant number: 0.00500001
#
# Time = 1.17437715
# pressure solve iterations =    1
# norm(u) = 2.01450437, norm(v) = 0.80406668
# Courant number: 0.00500001
#
# Time = 1.18228091
# pressure solve iterations =    1
# norm(u) = 2.01519129, norm(v) = 0.80360004
# Courant number: 0.00500001
#
# Time = 1.19017683
# pressure solve iterations =    1
# norm(u) = 2.01584252, norm(v) = 0.80312826
# Courant number: 0.00500001
#
# Time = 1.19806513
# pressure solve iterations =    1
# norm(u) = 2.01645943, norm(v) = 0.80265186
# Courant number: 0.00500001
#
# Time = 1.20594604
# pressure solve iterations =    1
# norm(u) = 2.01704330, norm(v) = 0.80217131
# Courant number: 0.00500001
#
# Time = 1.21381978
# pressure solve iterations =    1
# norm(u) = 2.01759538, norm(v) = 0.80168708
# Courant number: 0.00500001
#
# Time = 1.22168655
# pressure solve iterations =    1
# norm(u) = 2.01811689, norm(v) = 0.80119960
# Courant number: 0.00500001
#
# Time = 1.22954655
# pressure solve iterations =    1
# norm(u) = 2.01860897, norm(v) = 0.80070929
# Courant number: 0.00500001
#
# Time = 1.23739985
# pressure solve iterations =    1
# norm(u) = 2.01907271, norm(v) = 0.80021655
# Courant number: 0.00500001
#
# Time = 1.24524659
# pressure solve iterations =    1
# norm(u) = 2.01950919, norm(v) = 0.79972177
# Courant number: 0.00500001
#
# Time = 1.25308696
# pressure solve iterations =    1
# norm(u) = 2.01991946, norm(v) = 0.79922530
# Courant number: 0.00500001
#
# Time = 1.26092114
# pressure solve iterations =    1
# norm(u) = 2.02030450, norm(v) = 0.79872749
# Courant number: 0.00500001
#
# Time = 1.26874931
# pressure solve iterations =    1
# norm(u) = 2.02066530, norm(v) = 0.79822868
# Courant number: 0.00500001
#
# Time = 1.27657163
# pressure solve iterations =    1
# norm(u) = 2.02100277, norm(v) = 0.79772918
# Courant number: 0.00500001
#
# Time = 1.28438827
# pressure solve iterations =    1
# norm(u) = 2.02131781, norm(v) = 0.79722928
# Courant number: 0.00500001
#
# Time = 1.29219938
# pressure solve iterations =    1
# norm(u) = 2.02161127, norm(v) = 0.79672926
# Courant number: 0.00500001
#
# Time = 1.30000514
# pressure solve iterations =    1
# norm(u) = 2.02188400, norm(v) = 0.79622940
# Courant number: 0.00500001
#
# Time = 1.30780567
# pressure solve iterations =    1
# norm(u) = 2.02213677, norm(v) = 0.79572994
# Courant number: 0.00500001
#
# Time = 1.31560113
# pressure solve iterations =    1
# norm(u) = 2.02237037, norm(v) = 0.79523114
# Courant number: 0.00500001
#
# Time = 1.32339167
# pressure solve iterations =    1
# norm(u) = 2.02258552, norm(v) = 0.79473322
# Courant number: 0.00500001
#
# Time = 1.33117741
# pressure solve iterations =    1
# norm(u) = 2.02278295, norm(v) = 0.79423639
# Courant number: 0.00500001
#
# Time = 1.33895849
# pressure solve iterations =    1
# norm(u) = 2.02296335, norm(v) = 0.79374087
# Courant number: 0.00500001
#
# Time = 1.34673505
# pressure solve iterations =    1
# norm(u) = 2.02312736, norm(v) = 0.79324685
# Courant number: 0.00500001
#
# Time = 1.35450720
# pressure solve iterations =    1
# norm(u) = 2.02327563, norm(v) = 0.79275451
# Courant number: 0.00500001
#
# Time = 1.36227507
# pressure solve iterations =    1
# norm(u) = 2.02340879, norm(v) = 0.79226404
# Courant number: 0.00500001
#
# Time = 1.37003877
# pressure solve iterations =    1
# norm(u) = 2.02352741, norm(v) = 0.79177559
# Courant number: 0.00500001
#
# Time = 1.37779843
# pressure solve iterations =    1
# norm(u) = 2.02363208, norm(v) = 0.79128932
# Courant number: 0.00500001
#
# Time = 1.38555415
# pressure solve iterations =    1
# norm(u) = 2.02372334, norm(v) = 0.79080538
# Courant number: 0.00500000
#
# Time = 1.39330604
# pressure solve iterations =    1
# norm(u) = 2.02380172, norm(v) = 0.79032391
# Courant number: 0.00500000
#
# Time = 1.40105421
# pressure solve iterations =    1
# norm(u) = 2.02386775, norm(v) = 0.78984504
# Courant number: 0.00500000
#
# Time = 1.40879871
# pressure solve iterations =    1
# norm(u) = 2.02392191, norm(v) = 0.78936889
# Courant number: 0.00500000
#
# Time = 1.41653965
# pressure solve iterations =    1
# norm(u) = 2.02396467, norm(v) = 0.78889559
# Courant number: 0.00500000
#
# Time = 1.42427711
# pressure solve iterations =    1
# norm(u) = 2.02399651, norm(v) = 0.78842524
# Courant number: 0.00500000
#
# Time = 1.43201119
# pressure solve iterations =    1
# norm(u) = 2.02401786, norm(v) = 0.78795794
# Courant number: 0.00500000
#
# Time = 1.43974199
# pressure solve iterations =    1
# norm(u) = 2.02402917, norm(v) = 0.78749380
# Courant number: 0.00500000
#
# Time = 1.44746959
# pressure solve iterations =    1
# norm(u) = 2.02403083, norm(v) = 0.78703289
# Courant number: 0.00500000
#
# Time = 1.45519407
# pressure solve iterations =    1
# norm(u) = 2.02402326, norm(v) = 0.78657531
# Courant number: 0.00500000
#
# Time = 1.46291552
# pressure solve iterations =    1
# norm(u) = 2.02400684, norm(v) = 0.78612114
# Courant number: 0.00500000
#
# Time = 1.47063403
# pressure solve iterations =    1
# norm(u) = 2.02398195, norm(v) = 0.78567044
# Courant number: 0.00500000
#
# Time = 1.47834967
# pressure solve iterations =    1
# norm(u) = 2.02394893, norm(v) = 0.78522329
# Courant number: 0.00500000
#
# Time = 1.48606252
# pressure solve iterations =    1
# norm(u) = 2.02390815, norm(v) = 0.78477974
# Courant number: 0.00500000
#
# Time = 1.49377265
# pressure solve iterations =    1
# norm(u) = 2.02385993, norm(v) = 0.78433986
# Courant number: 0.00500000
#
# Time = 1.50148014
# pressure solve iterations =    1
# norm(u) = 2.02380460, norm(v) = 0.78390370
# Courant number: 0.00500000
#
# Time = 1.50918506
# pressure solve iterations =    1
# norm(u) = 2.02374246, norm(v) = 0.78347131
# Courant number: 0.00500000
#
# Time = 1.51688748
# pressure solve iterations =    1
# norm(u) = 2.02367383, norm(v) = 0.78304273
# Courant number: 0.00500000
#
# Time = 1.52458747
# pressure solve iterations =    1
# norm(u) = 2.02359900, norm(v) = 0.78261800
# Courant number: 0.00500000
#
# Time = 1.53228509
# pressure solve iterations =    1
# norm(u) = 2.02351823, norm(v) = 0.78219716
# Courant number: 0.00500000
#
# Time = 1.53998040
# pressure solve iterations =    1
# norm(u) = 2.02343182, norm(v) = 0.78178025
# Courant number: 0.00500000
#
# Time = 1.54767348
# pressure solve iterations =    1
# norm(u) = 2.02334000, norm(v) = 0.78136729
# Courant number: 0.00500000
#
# Time = 1.55536438
# pressure solve iterations =    1
# norm(u) = 2.02324305, norm(v) = 0.78095831
# Courant number: 0.00500000
#
# Time = 1.56305315
# pressure solve iterations =    1
# norm(u) = 2.02314120, norm(v) = 0.78055334
# Courant number: 0.00500000
#
# Time = 1.57073986
# pressure solve iterations =    1
# norm(u) = 2.02303470, norm(v) = 0.78015239
# Courant number: 0.00500000
#
# Time = 1.57842457
# pressure solve iterations =    1
# norm(u) = 2.02292375, norm(v) = 0.77975548
# Courant number: 0.00500000
#
# Time = 1.58610733
# pressure solve iterations =    1
# norm(u) = 2.02280860, norm(v) = 0.77936263
# Courant number: 0.00500000
#
# Time = 1.59378818
# pressure solve iterations =    1
# norm(u) = 2.02268945, norm(v) = 0.77897385
# Courant number: 0.00500000
#
# Time = 1.60146720
# pressure solve iterations =    1
# norm(u) = 2.02256650, norm(v) = 0.77858915
# Courant number: 0.00500000
#
# Time = 1.60914441
# pressure solve iterations =    1
# norm(u) = 2.02243995, norm(v) = 0.77820853
# Courant number: 0.00500000
#
# Time = 1.61681988
# pressure solve iterations =    1
# norm(u) = 2.02230999, norm(v) = 0.77783201
# Courant number: 0.00500000
#
# Time = 1.62449366
# pressure solve iterations =    1
# norm(u) = 2.02217682, norm(v) = 0.77745957
# Courant number: 0.00500000
#
# Time = 1.63216578
# pressure solve iterations =    1
# norm(u) = 2.02204059, norm(v) = 0.77709124
# Courant number: 0.00500000
#
# Time = 1.63983630
# pressure solve iterations =    1
# norm(u) = 2.02190150, norm(v) = 0.77672699
# Courant number: 0.00500000
#
# Time = 1.64750525
# pressure solve iterations =    1
# norm(u) = 2.02175970, norm(v) = 0.77636684
# Courant number: 0.00500000
#
# Time = 1.65517269
# pressure solve iterations =    1
# norm(u) = 2.02161535, norm(v) = 0.77601077
# Courant number: 0.00500000
#
# Time = 1.66283866
# pressure solve iterations =    1
# norm(u) = 2.02146862, norm(v) = 0.77565878
# Courant number: 0.00500000
#
# Time = 1.67050319
# pressure solve iterations =    1
# norm(u) = 2.02131964, norm(v) = 0.77531085
# Courant number: 0.00500000
#
# Time = 1.67816633
# pressure solve iterations =    1
# norm(u) = 2.02116856, norm(v) = 0.77496699
# Courant number: 0.00500000
#
# Time = 1.68582812
# pressure solve iterations =    1
# norm(u) = 2.02101553, norm(v) = 0.77462718
# Courant number: 0.00500000
#
# Time = 1.69348859
# pressure solve iterations =    1
# norm(u) = 2.02086067, norm(v) = 0.77429140
# Courant number: 0.00500000
#
# Time = 1.70114779
# pressure solve iterations =    1
# norm(u) = 2.02070411, norm(v) = 0.77395964
# Courant number: 0.00500000
#
# Time = 1.70880574
# pressure solve iterations =    1
# norm(u) = 2.02054599, norm(v) = 0.77363189
# Courant number: 0.00500000
#
# Time = 1.71646249
# pressure solve iterations =    1
# norm(u) = 2.02038641, norm(v) = 0.77330813
# Courant number: 0.00500000
#
# Time = 1.72411807
# pressure solve iterations =    1
# norm(u) = 2.02022551, norm(v) = 0.77298834
# Courant number: 0.00500000
#
# Time = 1.73177250
# pressure solve iterations =    1
# norm(u) = 2.02006338, norm(v) = 0.77267250
# Courant number: 0.00500000
#
# Time = 1.73942584
# pressure solve iterations =    1
# norm(u) = 2.01990014, norm(v) = 0.77236060
# Courant number: 0.00500000
#
# Time = 1.74707810
# pressure solve iterations =    1
# norm(u) = 2.01973589, norm(v) = 0.77205261
# Courant number: 0.00500000
#
# Time = 1.75472932
# pressure solve iterations =    1
# norm(u) = 2.01957074, norm(v) = 0.77174851
# Courant number: 0.00500000
#
# Time = 1.76237953
# pressure solve iterations =    1
# norm(u) = 2.01940477, norm(v) = 0.77144827
# Courant number: 0.00500000
#
# Time = 1.77002876
# pressure solve iterations =    1
# norm(u) = 2.01923809, norm(v) = 0.77115188
# Courant number: 0.00500000
#
# Time = 1.77767703
# pressure solve iterations =    1
# norm(u) = 2.01907078, norm(v) = 0.77085932
# Courant number: 0.00500000
#
# Time = 1.78532439
# pressure solve iterations =    1
# norm(u) = 2.01890293, norm(v) = 0.77057055
# Courant number: 0.00500000
#
# Time = 1.79297084
# pressure solve iterations =    1
# norm(u) = 2.01873463, norm(v) = 0.77028554
# Courant number: 0.00500000
#
# Time = 1.80061643
# pressure solve iterations =    1
# norm(u) = 2.01856595, norm(v) = 0.77000429
# Courant number: 0.00500000
#
# Time = 1.80826117
# pressure solve iterations =    1
# norm(u) = 2.01839697, norm(v) = 0.76972675
# Courant number: 0.00500000
#
# Time = 1.81590509
# pressure solve iterations =    1
# norm(u) = 2.01822777, norm(v) = 0.76945290
# Courant number: 0.00500000
#
# Time = 1.82354823
# pressure solve iterations =    1
# norm(u) = 2.01805842, norm(v) = 0.76918271
# Courant number: 0.00500000
#
# Time = 1.83119059
# pressure solve iterations =    1
# norm(u) = 2.01788898, norm(v) = 0.76891616
# Courant number: 0.00500000
#
# Time = 1.83883221
# pressure solve iterations =    1
# norm(u) = 2.01771953, norm(v) = 0.76865322
# Courant number: 0.00500000
#
# Time = 1.84647311
# pressure solve iterations =    1
# norm(u) = 2.01755013, norm(v) = 0.76839385
# Courant number: 0.00500000
#
# Time = 1.85411330
# pressure solve iterations =    1
# norm(u) = 2.01738084, norm(v) = 0.76813803
# Courant number: 0.00500000
#
# Time = 1.86175282
# pressure solve iterations =    1
# norm(u) = 2.01721172, norm(v) = 0.76788572
# Courant number: 0.00500000
#
# Time = 1.86939169
# pressure solve iterations =    1
# norm(u) = 2.01704283, norm(v) = 0.76763690
# Courant number: 0.00500000
#
# Time = 1.87702991
# pressure solve iterations =    1
# norm(u) = 2.01687422, norm(v) = 0.76739154
# Courant number: 0.00500000
#
# Time = 1.88466753
# pressure solve iterations =    1
# norm(u) = 2.01670594, norm(v) = 0.76714961
# Courant number: 0.00500000
#
# Time = 1.89230455
# pressure solve iterations =    1
# norm(u) = 2.01653804, norm(v) = 0.76691107
# Courant number: 0.00500000
#
# Time = 1.89994099
# pressure solve iterations =    1
# norm(u) = 2.01637058, norm(v) = 0.76667589
# Courant number: 0.00500000
#
# Time = 1.90757687
# pressure solve iterations =    1
# norm(u) = 2.01620360, norm(v) = 0.76644405
# Courant number: 0.00500000
#
# Time = 1.91521222
# pressure solve iterations =    1
# norm(u) = 2.01603714, norm(v) = 0.76621551
# Courant number: 0.00500000
#
# Time = 1.92284705
# pressure solve iterations =    1
# norm(u) = 2.01587124, norm(v) = 0.76599023
# Courant number: 0.00500000
#
# Time = 1.93048137
# pressure solve iterations =    1
# norm(u) = 2.01570595, norm(v) = 0.76576820
# Courant number: 0.00500000
#
# Time = 1.93811520
# pressure solve iterations =    1
# norm(u) = 2.01554131, norm(v) = 0.76554937
# Courant number: 0.00500000
#
# Time = 1.94574857
# pressure solve iterations =    1
# norm(u) = 2.01537735, norm(v) = 0.76533371
# Courant number: 0.00500000
#
# Time = 1.95338148
# pressure solve iterations =    1
# norm(u) = 2.01521411, norm(v) = 0.76512119
# Courant number: 0.00500000
#
# Time = 1.96101395
# pressure solve iterations =    1
# norm(u) = 2.01505163, norm(v) = 0.76491179
# Courant number: 0.00500000
#
# Time = 1.96864600
# pressure solve iterations =    1
# norm(u) = 2.01488992, norm(v) = 0.76470546
# Courant number: 0.00500000
#
# Time = 1.97627765
# pressure solve iterations =    1
# norm(u) = 2.01472904, norm(v) = 0.76450217
# Courant number: 0.00500000
#
# Time = 1.98390889
# pressure solve iterations =    1
# norm(u) = 2.01456900, norm(v) = 0.76430190
# Courant number: 0.00500000
#
# Time = 1.99153976
# pressure solve iterations =    1
# norm(u) = 2.01440984, norm(v) = 0.76410461
# Courant number: 0.00500000
#
# Time = 1.99917027
# pressure solve iterations =    1
# norm(u) = 2.01425158, norm(v) = 0.76391027
# Courant number: 0.00500000
#
# Time = 2.00680042
# pressure solve iterations =    1
# norm(u) = 2.01409424, norm(v) = 0.76371884
# Courant number: 0.00500000
#
# Time = 2.01443023
# pressure solve iterations =    1
# norm(u) = 2.01393786, norm(v) = 0.76353030
# Courant number: 0.00500000
#
# Time = 2.02205971
# pressure solve iterations =    1
# norm(u) = 2.01378246, norm(v) = 0.76334460
# Courant number: 0.00500000
#
# Time = 2.02968889
# pressure solve iterations =    1
# norm(u) = 2.01362805, norm(v) = 0.76316173
# Courant number: 0.00500000
#
# Time = 2.03731776
# pressure solve iterations =    1
# norm(u) = 2.01347465, norm(v) = 0.76298164
# Courant number: 0.00500000
#
# Time = 2.04494633
# pressure solve iterations =    1
# norm(u) = 2.01332230, norm(v) = 0.76280431
# Courant number: 0.00500000
#
# Time = 2.05257463
# pressure solve iterations =    1
# norm(u) = 2.01317100, norm(v) = 0.76262971
# Courant number: 0.00500000
#
# Time = 2.06020267
# pressure solve iterations =    1
# norm(u) = 2.01302077, norm(v) = 0.76245780
# Courant number: 0.00500000
#
# Time = 2.06783044
# pressure solve iterations =    1
# norm(u) = 2.01287164, norm(v) = 0.76228854
# Courant number: 0.00500000
#
# Time = 2.07545797
# pressure solve iterations =    1
# norm(u) = 2.01272360, norm(v) = 0.76212192
# Courant number: 0.00500000
#
# Time = 2.08308526
# pressure solve iterations =    1
# norm(u) = 2.01257669, norm(v) = 0.76195789
# Courant number: 0.00500000
#
# Time = 2.09071233
# pressure solve iterations =    1
# norm(u) = 2.01243092, norm(v) = 0.76179644
# Courant number: 0.00500000
#
# Time = 2.09833918
# pressure solve iterations =    1
# norm(u) = 2.01228629, norm(v) = 0.76163751
# Courant number: 0.00500000
#
# Time = 2.10596582
# pressure solve iterations =    1
# norm(u) = 2.01214281, norm(v) = 0.76148110
# Courant number: 0.00500000
#
# Time = 2.11359226
# pressure solve iterations =    1
# norm(u) = 2.01200051, norm(v) = 0.76132715
# Courant number: 0.00500000
#
# Time = 2.12121852
# pressure solve iterations =    1
# norm(u) = 2.01185938, norm(v) = 0.76117565
# Courant number: 0.00500000
#
# Time = 2.12884459
# pressure solve iterations =    1
# norm(u) = 2.01171945, norm(v) = 0.76102657
# Courant number: 0.00500000
#
# Time = 2.13647050
# pressure solve iterations =    1
# norm(u) = 2.01158071, norm(v) = 0.76087986
# Courant number: 0.00500000
#
# Time = 2.14409623
# pressure solve iterations =    1
# norm(u) = 2.01144318, norm(v) = 0.76073552
# Courant number: 0.00500000
# Steady state reached at time:  2.1458501322532073
# Time taken by calculation =  217.51765394210815

# %%
# set up figure
fig = plt.figure(figsize=(21, 7))
ax1 = fig.add_subplot(121)
cont = ax1.contourf(X,Y,T, cmap=cm.coolwarm)
fig.colorbar(cont)
# don't plot at every gird point - every 5th
ax1.set_xlim(-0.001, 0.01)
ax1.set_ylim(-0.0001, 0.005)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - pressure and velocity vectors', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pressure driven problem - pressure and velocity vectors')

# %% [markdown]
# ### Add a function to calculate the avergage outflow temperature

# %%
def calculate_average_outflow_temperature(T, u, v, dx, dy):
    """
    Calculate the flow average outflow temperature.
    
    Parameters:
    T : 2D array of temperature values.
    u : 2D array of horizontal velocity values.
    v : 2D array of vertical velocity values.
    dx: Spatial step in the x-direction.
    dy: Spatial step in the y-direction.

    Returns:
    float : The average outflow temperature.
    """
    # Assume the outflow is on the right half of the top boundary.
    # We will take the top row for v velocities and the corresponding temperatures.
    half_Nx = len(T) // 2
    
    # Get the right half of the top boundary temperatures and velocities.
    outflow_velocities = v[0, half_Nx:]

    outflow_temps = T[len(T)//2:,-1]
    outflow_velocities = v[len(T)//2:,-1]
    
    # Calculate the weighted average of the temperature.
    # The weighting factor is the outflow velocity.
    weighted_temps = outflow_temps * outflow_velocities
    
    # Calculate the average outflow velocity.
    avg_outflow_velocity = np.mean(outflow_velocities)
    
    # If the average outflow velocity is zero or very small, return the simple average temperature
    # to avoid division by zero.
    if np.abs(avg_outflow_velocity) < 1e-8:
        return np.mean(outflow_temps)
    
    # Calculate the flow average outflow temperature.
    flow_avg_outflow_temp = np.sum(weighted_temps) / np.sum(outflow_velocities)
    
    return flow_avg_outflow_temp

# Example usage:
# Assuming T, u, and v are defined as per the provided Navier-Stokes simulation results.
# Calculate the average outflow temperature.
average_outflow_temp = calculate_average_outflow_temperature(T, u, v, dx, dy)
print("The flow average outflow temperature is: {:.2f} C".format(average_outflow_temp))
# Out:
# The flow average outflow temperature is: 55.52 C

# %% [markdown]
# # D) Parameter investigation
# To investigate the effect of the physical parameters on our final result (average outflow temperature), we have to first understand our field of simulation. We are fundamentally solve an advection-diffusion equation, which the advection term is calculated by solving a pressure driven navier-stokes equation.
#
# To step back from the math and physics equation, the system is a heater that feeds in cool water from the inlet to the outlet, and the wall acts as the heating compartment. The average outflow temperature thus is dominated by how fast the flow of water and how fast is the heat diffused into the water. If the water runs too fast, we do not have enough time to allow heating through heat diffusion, whereas if the water runs too slow or the heat diffuses really fast, the outflow will become very hot, as the inlet cool water will be heated completely.
#
# Thus the answer is basically dominated by the Peclet number which in the equation is:
# $$Pe = \frac{U*L}{K}$$
# where U is the velocity magnitude, L is the characteristic length and K is the diffusion coefficient. If Pe is much greater than 1, the system is Advection dominated, if Pe is way less than 1, the system is diffusion dominated. As we are solving a pressure driven navier-stokes equation, the velocity is govern by the pressure drop, therefore I would investigate the effect of pressure drop vs the diffusitivity over the final average outflow temperature.
#
# First I will define a function that plots the perclet number field to help visualize the field.

# %%
def plot_peclet_number_field(u, v, Lx, Ly, D):
    """
    Calculate and plot the Péclet number field.

    Parameters:
    u : 2D array
        Horizontal velocity field.
    v : 2D array
        Vertical velocity field.
    dx : float
        Spatial step in the x-direction.
    dy : float
        Spatial step in the y-direction.
    D : float
        Diffusion coefficient.
    Lx : float
        Length of the domain in the x-direction.
    Ly : float
        Length of the domain in the y-direction.
    """
    # Calculate velocity magnitude
    U = np.sqrt(u**2 + v**2)
    
    # Characteristic length (use smaller of domain dimensions)
    L = min(Lx, Ly)

    # Calculate Péclet number field
    Pe_field = U * L / D

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.contourf(X,Y,Pe_field, cmap=cm.viridis)
    plt.colorbar(label='Péclet Number')
    plt.title('Péclet Number Field')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()

# %%
# Example usage
# Assuming you have the velocity fields 'u' and 'v', and the domain dimensions 'Lx', 'Ly',
# and a given diffusion coefficient 'D'.
plot_peclet_number_field(u, v, k, Lx, Ly)

# %% [markdown]
# Create simulation that has double the pressure drop.

# %%
# redefine physical parameters
rho = 1000
nu = 0.001/1000.
k = 5e-6
nu = 0.001/1000.

# define spatial mesh
# Size of rectangular domain
Lx = 0.01
Ly = 0.005
P_max = 1

# Number of grid points in each direction, including boundary nodes
Nx = 51
Ny = 26

# hence the mesh spacing
dx = Lx/(Nx-1)
dy = Ly/(Ny-1)

# read the docs to see the ordering that mgrid gives us
X, Y = np.mgrid[0:Nx:1, 0:Ny:1]
X = dx*X
Y = dy*Y
# the following is an alternative to the three lines above
#X, Y = np.mgrid[0: Lx + 1e-10: dx, 0: Ly + 1e-10: dy]
# but without the need to add a "small" increement to ensure
# the Lx and Ly end points are included

# initialise independent variables
u = np.zeros_like(X)
v = np.zeros_like(X)
p = np.zeros_like(X)
T = np.zeros_like(X)

# Apply Dirichlet BCs to u and v - the code below doesn't touch 
# these so we can do this once outside the time loop
u[:, -1] = 0
u[:, 0] = 0
u[0, :] = 0
u[-1, :] = 0
v[:, -1] = 0
v[:, 0] = 0
v[0, :] = 0
v[-1, :] = 0
imax = len(u)
jmax = np.size(u)//imax
p[0,] = P_max
p[imax//2:, -1] = 0.0


# Boundary conditions
T[0,:] = 20  # Inlet temperature in degrees Celsius
T[len(T)//2:,-1] = 0.0  #Top boundary
T[:len(T)//2,-1] = 100
T[-1,:] = 100  # Right boundary temperature 
T[1:-1,0] = 100 # bottom boundary temperature

courant = 0.005
dt_min = 1.e-5

t_end = 3
import time
start = time.time()
u, v, p ,T= solve_NS_with_Temp_update(u, v, p, T, k, rho, nu, courant, dt_min, t_end, dx, dy, rtol = 1.e-6, logs = True, outint = 1000)
end = time.time()
print('Time taken by calculation = ', end - start)
# Out:
# Time = 0.01000000
# pressure solve iterations =    2
# norm(u) = 0.03478825, norm(v) = 0.01760152
# Courant number: 0.00018845
#
# Time = 0.02000000
# pressure solve iterations =    2
# norm(u) = 0.06857397, norm(v) = 0.03440916
# Courant number: 0.00031995
#
# Time = 0.03000000
# pressure solve iterations =    3
# norm(u) = 0.10148697, norm(v) = 0.05057645
# Courant number: 0.00042358
#
# Time = 0.04000000
# pressure solve iterations =    2
# norm(u) = 0.13361863, norm(v) = 0.06617387
# Courant number: 0.00051657
#
# Time = 0.05000000
# pressure solve iterations =    2
# norm(u) = 0.16503892, norm(v) = 0.08125501
# Courant number: 0.00059211
#
# Time = 0.06000000
# pressure solve iterations =    2
# norm(u) = 0.19579899, norm(v) = 0.09586577
# Courant number: 0.00065964
#
# Time = 0.07000000
# pressure solve iterations =    2
# norm(u) = 0.22593560, norm(v) = 0.11004625
# Courant number: 0.00072904
#
# Time = 0.08000000
# pressure solve iterations =    1
# norm(u) = 0.25547431, norm(v) = 0.12383099
# Courant number: 0.00079268
#
# Time = 0.09000000
# pressure solve iterations =    2
# norm(u) = 0.28443172, norm(v) = 0.13724881
# Courant number: 0.00085166
#
# Time = 0.10000000
# pressure solve iterations =    2
# norm(u) = 0.31281698, norm(v) = 0.15032274
# Courant number: 0.00090680
#
# Time = 0.11000000
# pressure solve iterations =    2
# norm(u) = 0.34063307, norm(v) = 0.16307013
# Courant number: 0.00095874
#
# Time = 0.12000000
# pressure solve iterations =    2
# norm(u) = 0.36787795, norm(v) = 0.17550289
# Courant number: 0.00100798
#
# Time = 0.13000000
# pressure solve iterations =    2
# norm(u) = 0.39454556, norm(v) = 0.18762797
# Courant number: 0.00105661
#
# Time = 0.14000000
# pressure solve iterations =    2
# norm(u) = 0.42062689, norm(v) = 0.19944793
# Courant number: 0.00110521
#
# Time = 0.15000000
# pressure solve iterations =    2
# norm(u) = 0.44611102, norm(v) = 0.21096179
# Courant number: 0.00115187
#
# Time = 0.16000000
# pressure solve iterations =    2
# norm(u) = 0.47098607, norm(v) = 0.22216584
# Courant number: 0.00119682
#
# Time = 0.17000000
# pressure solve iterations =    2
# norm(u) = 0.49524019, norm(v) = 0.23305455
# Courant number: 0.00124023
#
# Time = 0.18000000
# pressure solve iterations =    2
# norm(u) = 0.51886238, norm(v) = 0.24362145
# Courant number: 0.00128222
#
# Time = 0.19000000
# pressure solve iterations =    3
# norm(u) = 0.54184317, norm(v) = 0.25385987
# Courant number: 0.00132335
#
# Time = 0.20000000
# pressure solve iterations =    3
# norm(u) = 0.56417518, norm(v) = 0.26376362
# Courant number: 0.00136705
#
# Time = 0.21000000
# pressure solve iterations =    2
# norm(u) = 0.58585338, norm(v) = 0.27332746
# Courant number: 0.00140950
#
# Time = 0.22000000
# pressure solve iterations =    2
# norm(u) = 0.60687535, norm(v) = 0.28254741
# Courant number: 0.00145075
#
# Time = 0.23000000
# pressure solve iterations =    2
# norm(u) = 0.62724115, norm(v) = 0.29142093
# Courant number: 0.00149084
#
# Time = 0.24000000
# pressure solve iterations =    2
# norm(u) = 0.64695327, norm(v) = 0.29994702
# Courant number: 0.00152979
#
# Time = 0.25000000
# pressure solve iterations =    2
# norm(u) = 0.66601633, norm(v) = 0.30812607
# Courant number: 0.00156763
#
# Time = 0.26000000
# pressure solve iterations =    2
# norm(u) = 0.68443679, norm(v) = 0.31595984
# Courant number: 0.00160440
#
# Time = 0.27000000
# pressure solve iterations =    2
# norm(u) = 0.70222265, norm(v) = 0.32345132
# Courant number: 0.00164014
#
# Time = 0.28000000
# pressure solve iterations =    2
# norm(u) = 0.71938309, norm(v) = 0.33060456
# Courant number: 0.00167486
#
# Time = 0.29000000
# pressure solve iterations =    2
# norm(u) = 0.73592818, norm(v) = 0.33742453
# Courant number: 0.00170862
#
# Time = 0.30000000
# pressure solve iterations =    2
# norm(u) = 0.75186864, norm(v) = 0.34391702
# Courant number: 0.00174183
#
# Time = 0.31000000
# pressure solve iterations =    2
# norm(u) = 0.76721565, norm(v) = 0.35008846
# Courant number: 0.00177553
#
# Time = 0.32000000
# pressure solve iterations =    2
# norm(u) = 0.78198070, norm(v) = 0.35594589
# Courant number: 0.00180853
#
# Time = 0.33000000
# pressure solve iterations =    2
# norm(u) = 0.79617548, norm(v) = 0.36149687
# Courant number: 0.00184065
#
# Time = 0.34000000
# pressure solve iterations =    1
# norm(u) = 0.80981186, norm(v) = 0.36674937
# Courant number: 0.00187192
#
# Time = 0.35000000
# pressure solve iterations =    1
# norm(u) = 0.82290189, norm(v) = 0.37171172
# Courant number: 0.00190234
#
# Time = 0.36000000
# pressure solve iterations =    1
# norm(u) = 0.83545775, norm(v) = 0.37639260
# Courant number: 0.00193194
#
# Time = 0.37000000
# pressure solve iterations =    1
# norm(u) = 0.84749185, norm(v) = 0.38080083
# Courant number: 0.00196073
#
# Time = 0.38000000
# pressure solve iterations =    1
# norm(u) = 0.85901682, norm(v) = 0.38494547
# Courant number: 0.00198872
#
# Time = 0.39000000
# pressure solve iterations =    1
# norm(u) = 0.87004550, norm(v) = 0.38883568
# Courant number: 0.00201594
#
# Time = 0.40000000
# pressure solve iterations =    1
# norm(u) = 0.88059097, norm(v) = 0.39248069
# Courant number: 0.00204239
#
# Time = 0.41000000
# pressure solve iterations =    2
# norm(u) = 0.89066653, norm(v) = 0.39588972
# Courant number: 0.00206808
#
# Time = 0.42000000
# pressure solve iterations =    1
# norm(u) = 0.90028564, norm(v) = 0.39907202
# Courant number: 0.00209303
#
# Time = 0.43000000
# pressure solve iterations =    1
# norm(u) = 0.90946198, norm(v) = 0.40203663
# Courant number: 0.00211726
#
# Time = 0.44000000
# pressure solve iterations =    1
# norm(u) = 0.91820933, norm(v) = 0.40479253
# Courant number: 0.00214077
#
# Time = 0.45000000
# pressure solve iterations =    1
# norm(u) = 0.92654156, norm(v) = 0.40734856
# Courant number: 0.00216359
#
# Time = 0.46000000
# pressure solve iterations =    1
# norm(u) = 0.93447259, norm(v) = 0.40971330
# Courant number: 0.00218572
#
# Time = 0.47000000
# pressure solve iterations =    1
# norm(u) = 0.94201635, norm(v) = 0.41189516
# Courant number: 0.00220718
#
# Time = 0.48000000
# pressure solve iterations =    1
# norm(u) = 0.94918676, norm(v) = 0.41390235
# Courant number: 0.00222799
#
# Time = 0.49000000
# pressure solve iterations =    1
# norm(u) = 0.95599759, norm(v) = 0.41574292
# Courant number: 0.00224845
#
# Time = 0.50000000
# pressure solve iterations =    1
# norm(u) = 0.96246255, norm(v) = 0.41742466
# Courant number: 0.00226881
#
# Time = 0.51000000
# pressure solve iterations =    1
# norm(u) = 0.96859513, norm(v) = 0.41895522
# Courant number: 0.00228852
#
# Time = 0.52000000
# pressure solve iterations =    1
# norm(u) = 0.97440861, norm(v) = 0.42034205
# Courant number: 0.00230760
#
# Time = 0.53000000
# pressure solve iterations =    1
# norm(u) = 0.97991610, norm(v) = 0.42159226
# Courant number: 0.00232606
#
# Time = 0.54000000
# pressure solve iterations =    1
# norm(u) = 0.98513046, norm(v) = 0.42271277
# Courant number: 0.00234393
#
# Time = 0.55000000
# pressure solve iterations =    1
# norm(u) = 0.99006431, norm(v) = 0.42371030
# Courant number: 0.00236122
#
# Time = 0.56000000
# pressure solve iterations =    1
# norm(u) = 0.99473000, norm(v) = 0.42459134
# Courant number: 0.00237793
#
# Time = 0.57000000
# pressure solve iterations =    1
# norm(u) = 0.99913957, norm(v) = 0.42536222
# Courant number: 0.00239409
#
# Time = 0.58000000
# pressure solve iterations =    1
# norm(u) = 1.00330472, norm(v) = 0.42602910
# Courant number: 0.00240972
#
# Time = 0.59000000
# pressure solve iterations =    1
# norm(u) = 1.00723681, norm(v) = 0.42659784
# Courant number: 0.00242482
#
# Time = 0.60000000
# pressure solve iterations =    1
# norm(u) = 1.01094696, norm(v) = 0.42707404
# Courant number: 0.00243942
#
# Time = 0.61000000
# pressure solve iterations =    1
# norm(u) = 1.01444579, norm(v) = 0.42746331
# Courant number: 0.00245352
#
# Time = 0.62000000
# pressure solve iterations =    1
# norm(u) = 1.01774366, norm(v) = 0.42777080
# Courant number: 0.00246715
#
# Time = 0.63000000
# pressure solve iterations =    1
# norm(u) = 1.02085056, norm(v) = 0.42800154
# Courant number: 0.00248031
#
# Time = 0.64000000
# pressure solve iterations =    1
# norm(u) = 1.02377615, norm(v) = 0.42816034
# Courant number: 0.00249303
#
# Time = 0.65000000
# pressure solve iterations =    1
# norm(u) = 1.02652971, norm(v) = 0.42825181
# Courant number: 0.00250532
#
# Time = 0.66000000
# pressure solve iterations =    1
# norm(u) = 1.02912021, norm(v) = 0.42828039
# Courant number: 0.00251719
#
# Time = 0.67000000
# pressure solve iterations =    1
# norm(u) = 1.03155625, norm(v) = 0.42825031
# Courant number: 0.00252866
#
# Time = 0.68000000
# pressure solve iterations =    1
# norm(u) = 1.03384608, norm(v) = 0.42816562
# Courant number: 0.00253974
#
# Time = 0.69000000
# pressure solve iterations =    1
# norm(u) = 1.03599759, norm(v) = 0.42803020
# Courant number: 0.00255044
#
# Time = 0.70000000
# pressure solve iterations =    1
# norm(u) = 1.03801833, norm(v) = 0.42784773
# Courant number: 0.00256078
#
# Time = 0.71000000
# pressure solve iterations =    1
# norm(u) = 1.03991553, norm(v) = 0.42762170
# Courant number: 0.00257078
#
# Time = 0.72000000
# pressure solve iterations =    1
# norm(u) = 1.04169609, norm(v) = 0.42735545
# Courant number: 0.00258043
#
# Time = 0.73000000
# pressure solve iterations =    1
# norm(u) = 1.04336655, norm(v) = 0.42705222
# Courant number: 0.00258977
#
# Time = 0.74000000
# pressure solve iterations =    1
# norm(u) = 1.04493307, norm(v) = 0.42671509
# Courant number: 0.00259879
#
# Time = 0.75000000
# pressure solve iterations =    1
# norm(u) = 1.04640151, norm(v) = 0.42634689
# Courant number: 0.00260751
#
# Time = 0.76000000
# pressure solve iterations =    1
# norm(u) = 1.04777752, norm(v) = 0.42595016
# Courant number: 0.00261594
#
# Time = 0.77000000
# pressure solve iterations =    1
# norm(u) = 1.04906645, norm(v) = 0.42552745
# Courant number: 0.00262410
#
# Time = 0.78000000
# pressure solve iterations =    1
# norm(u) = 1.05027335, norm(v) = 0.42508114
# Courant number: 0.00263199
#
# Time = 0.79000000
# pressure solve iterations =    1
# norm(u) = 1.05140303, norm(v) = 0.42461347
# Courant number: 0.00263962
#
# Time = 0.80000000
# pressure solve iterations =    1
# norm(u) = 1.05246007, norm(v) = 0.42412659
# Courant number: 0.00264700
#
# Time = 0.81000000
# pressure solve iterations =    1
# norm(u) = 1.05344877, norm(v) = 0.42362256
# Courant number: 0.00265414
#
# Time = 0.82000000
# pressure solve iterations =    1
# norm(u) = 1.05437319, norm(v) = 0.42310325
# Courant number: 0.00266106
#
# Time = 0.83000000
# pressure solve iterations =    1
# norm(u) = 1.05523718, norm(v) = 0.42257044
# Courant number: 0.00266775
#
# Time = 0.84000000
# pressure solve iterations =    1
# norm(u) = 1.05604439, norm(v) = 0.42202578
# Courant number: 0.00267424
#
# Time = 0.85000000
# pressure solve iterations =    1
# norm(u) = 1.05679821, norm(v) = 0.42147086
# Courant number: 0.00268052
#
# Time = 0.86000000
# pressure solve iterations =    1
# norm(u) = 1.05750187, norm(v) = 0.42090713
# Courant number: 0.00268660
#
# Time = 0.87000000
# pressure solve iterations =    1
# norm(u) = 1.05815838, norm(v) = 0.42033595
# Courant number: 0.00269250
#
# Time = 0.88000000
# pressure solve iterations =    1
# norm(u) = 1.05877059, norm(v) = 0.41975859
# Courant number: 0.00269821
#
# Time = 0.89000000
# pressure solve iterations =    1
# norm(u) = 1.05934118, norm(v) = 0.41917623
# Courant number: 0.00270375
#
# Time = 0.90000000
# pressure solve iterations =    1
# norm(u) = 1.05987264, norm(v) = 0.41858996
# Courant number: 0.00270912
#
# Time = 0.91000000
# pressure solve iterations =    1
# norm(u) = 1.06036736, norm(v) = 0.41800081
# Courant number: 0.00271433
#
# Time = 0.92000000
# pressure solve iterations =    1
# norm(u) = 1.06082757, norm(v) = 0.41740974
# Courant number: 0.00271938
#
# Time = 0.93000000
# pressure solve iterations =    1
# norm(u) = 1.06125534, norm(v) = 0.41681765
# Courant number: 0.00272429
#
# Time = 0.94000000
# pressure solve iterations =    1
# norm(u) = 1.06165265, norm(v) = 0.41622533
# Courant number: 0.00272904
#
# Time = 0.95000000
# pressure solve iterations =    1
# norm(u) = 1.06202135, norm(v) = 0.41563355
# Courant number: 0.00273366
#
# Time = 0.96000000
# pressure solve iterations =    1
# norm(u) = 1.06236315, norm(v) = 0.41504301
# Courant number: 0.00273815
#
# Time = 0.97000000
# pressure solve iterations =    1
# norm(u) = 1.06267968, norm(v) = 0.41445436
# Courant number: 0.00274250
#
# Time = 0.98000000
# pressure solve iterations =    1
# norm(u) = 1.06297247, norm(v) = 0.41386819
# Courant number: 0.00274673
#
# Time = 0.99000000
# pressure solve iterations =    1
# norm(u) = 1.06324292, norm(v) = 0.41328503
# Courant number: 0.00275083
#
# Time = 1.00000000
# pressure solve iterations =    1
# norm(u) = 1.06349238, norm(v) = 0.41270538
# Courant number: 0.00275482
#
# Time = 1.01000000
# pressure solve iterations =    1
# norm(u) = 1.06372210, norm(v) = 0.41212970
# Courant number: 0.00275870
#
# Time = 1.02000000
# pressure solve iterations =    1
# norm(u) = 1.06393325, norm(v) = 0.41155840
# Courant number: 0.00276246
#
# Time = 1.03000000
# pressure solve iterations =    1
# norm(u) = 1.06412693, norm(v) = 0.41099184
# Courant number: 0.00276612
#
# Time = 1.04000000
# pressure solve iterations =    1
# norm(u) = 1.06430417, norm(v) = 0.41043038
# Courant number: 0.00276968
#
# Time = 1.05000000
# pressure solve iterations =    1
# norm(u) = 1.06446592, norm(v) = 0.40987432
# Courant number: 0.00277314
#
# Time = 1.06000000
# pressure solve iterations =    1
# norm(u) = 1.06461307, norm(v) = 0.40932396
# Courant number: 0.00277650
#
# Time = 1.07000000
# pressure solve iterations =    1
# norm(u) = 1.06474645, norm(v) = 0.40877950
# Courant number: 0.00277977
#
# Time = 1.08000000
# pressure solve iterations =    1
# norm(u) = 1.06486685, norm(v) = 0.40824117
# Courant number: 0.00278295
#
# Time = 1.09000000
# pressure solve iterations =    1
# norm(u) = 1.06497500, norm(v) = 0.40770918
# Courant number: 0.00278604
#
# Time = 1.10000000
# pressure solve iterations =    1
# norm(u) = 1.06507158, norm(v) = 0.40718365
# Courant number: 0.00278905
#
# Time = 1.11000000
# pressure solve iterations =    1
# norm(u) = 1.06515726, norm(v) = 0.40666472
# Courant number: 0.00279197
#
# Time = 1.12000000
# pressure solve iterations =    1
# norm(u) = 1.06523266, norm(v) = 0.40615251
# Courant number: 0.00279481
#
# Time = 1.13000000
# pressure solve iterations =    1
# norm(u) = 1.06529838, norm(v) = 0.40564716
# Courant number: 0.00279758
#
# Time = 1.14000000
# pressure solve iterations =    1
# norm(u) = 1.06535496, norm(v) = 0.40514874
# Courant number: 0.00280027
#
# Time = 1.15000000
# pressure solve iterations =    1
# norm(u) = 1.06540294, norm(v) = 0.40465735
# Courant number: 0.00280289
#
# Time = 1.16000000
# pressure solve iterations =    1
# norm(u) = 1.06544281, norm(v) = 0.40417305
# Courant number: 0.00280544
#
# Time = 1.17000000
# pressure solve iterations =    1
# norm(u) = 1.06547504, norm(v) = 0.40369589
# Courant number: 0.00280791
#
# Time = 1.18000000
# pressure solve iterations =    1
# norm(u) = 1.06550005, norm(v) = 0.40322592
# Courant number: 0.00281033
#
# Time = 1.19000000
# pressure solve iterations =    1
# norm(u) = 1.06551826, norm(v) = 0.40276317
# Courant number: 0.00281267
#
# Time = 1.20000000
# pressure solve iterations =    1
# norm(u) = 1.06553005, norm(v) = 0.40230764
# Courant number: 0.00281495
#
# Time = 1.21000000
# pressure solve iterations =    1
# norm(u) = 1.06553579, norm(v) = 0.40185936
# Courant number: 0.00281717
#
# Time = 1.22000000
# pressure solve iterations =    1
# norm(u) = 1.06553582, norm(v) = 0.40141832
# Courant number: 0.00281933
#
# Time = 1.23000000
# pressure solve iterations =    1
# norm(u) = 1.06553045, norm(v) = 0.40098451
# Courant number: 0.00282143
#
# Time = 1.24000000
# pressure solve iterations =    1
# norm(u) = 1.06552000, norm(v) = 0.40055790
# Courant number: 0.00282348
#
# Time = 1.25000000
# pressure solve iterations =    1
# norm(u) = 1.06550475, norm(v) = 0.40013847
# Courant number: 0.00282546
#
# Time = 1.26000000
# pressure solve iterations =    1
# norm(u) = 1.06548499, norm(v) = 0.39972618
# Courant number: 0.00282740
#
# Time = 1.27000000
# pressure solve iterations =    1
# norm(u) = 1.06546096, norm(v) = 0.39932100
# Courant number: 0.00282928
#
# Time = 1.28000000
# pressure solve iterations =    1
# norm(u) = 1.06543292, norm(v) = 0.39892289
# Courant number: 0.00283111
#
# Time = 1.29000000
# pressure solve iterations =    1
# norm(u) = 1.06540109, norm(v) = 0.39853178
# Courant number: 0.00283289
#
# Time = 1.30000000
# pressure solve iterations =    1
# norm(u) = 1.06536570, norm(v) = 0.39814764
# Courant number: 0.00283463
#
# Time = 1.31000000
# pressure solve iterations =    1
# norm(u) = 1.06532695, norm(v) = 0.39777040
# Courant number: 0.00283631
#
# Time = 1.32000000
# pressure solve iterations =    1
# norm(u) = 1.06528503, norm(v) = 0.39740000
# Courant number: 0.00283795
#
# Time = 1.33000000
# pressure solve iterations =    1
# norm(u) = 1.06524014, norm(v) = 0.39703638
# Courant number: 0.00283954
#
# Time = 1.34000000
# pressure solve iterations =    1
# norm(u) = 1.06519246, norm(v) = 0.39667945
# Courant number: 0.00284109
#
# Time = 1.35000000
# pressure solve iterations =    1
# norm(u) = 1.06514215, norm(v) = 0.39632916
# Courant number: 0.00284260
#
# Time = 1.36000000
# pressure solve iterations =    1
# norm(u) = 1.06508939, norm(v) = 0.39598543
# Courant number: 0.00284407
#
# Time = 1.37000000
# pressure solve iterations =    1
# norm(u) = 1.06503431, norm(v) = 0.39564819
# Courant number: 0.00284549
#
# Time = 1.38000000
# pressure solve iterations =    1
# norm(u) = 1.06497707, norm(v) = 0.39531736
# Courant number: 0.00284688
#
# Time = 1.39000000
# pressure solve iterations =    1
# norm(u) = 1.06491780, norm(v) = 0.39499285
# Courant number: 0.00284822
#
# Time = 1.40000000
# pressure solve iterations =    1
# norm(u) = 1.06485664, norm(v) = 0.39467460
# Courant number: 0.00284953
#
# Time = 1.41000000
# pressure solve iterations =    1
# norm(u) = 1.06479372, norm(v) = 0.39436251
# Courant number: 0.00285080
#
# Time = 1.42000000
# pressure solve iterations =    1
# norm(u) = 1.06472915, norm(v) = 0.39405651
# Courant number: 0.00285204
#
# Time = 1.43000000
# pressure solve iterations =    1
# norm(u) = 1.06466306, norm(v) = 0.39375652
# Courant number: 0.00285324
#
# Time = 1.44000000
# pressure solve iterations =    1
# norm(u) = 1.06459554, norm(v) = 0.39346244
# Courant number: 0.00285441
#
# Time = 1.45000000
# pressure solve iterations =    1
# norm(u) = 1.06452670, norm(v) = 0.39317420
# Courant number: 0.00285554
#
# Time = 1.46000000
# pressure solve iterations =    1
# norm(u) = 1.06445666, norm(v) = 0.39289171
# Courant number: 0.00285665
#
# Time = 1.47000000
# pressure solve iterations =    1
# norm(u) = 1.06438549, norm(v) = 0.39261489
# Courant number: 0.00285785
#
# Time = 1.48000000
# pressure solve iterations =    1
# norm(u) = 1.06431329, norm(v) = 0.39234365
# Courant number: 0.00285903
#
# Time = 1.49000000
# pressure solve iterations =    1
# norm(u) = 1.06424014, norm(v) = 0.39207790
# Courant number: 0.00286019
#
# Time = 1.50000000
# pressure solve iterations =    1
# norm(u) = 1.06416614, norm(v) = 0.39181757
# Courant number: 0.00286131
#
# Time = 1.51000000
# pressure solve iterations =    1
# norm(u) = 1.06409136, norm(v) = 0.39156256
# Courant number: 0.00286240
#
# Time = 1.52000000
# pressure solve iterations =    1
# norm(u) = 1.06401588, norm(v) = 0.39131279
# Courant number: 0.00286346
#
# Time = 1.53000000
# pressure solve iterations =    1
# norm(u) = 1.06393977, norm(v) = 0.39106819
# Courant number: 0.00286449
#
# Time = 1.54000000
# pressure solve iterations =    1
# norm(u) = 1.06386309, norm(v) = 0.39082866
# Courant number: 0.00286550
#
# Time = 1.55000000
# pressure solve iterations =    1
# norm(u) = 1.06378592, norm(v) = 0.39059412
# Courant number: 0.00286647
#
# Time = 1.56000000
# pressure solve iterations =    1
# norm(u) = 1.06370832, norm(v) = 0.39036448
# Courant number: 0.00286742
#
# Time = 1.57000000
# pressure solve iterations =    1
# norm(u) = 1.06363034, norm(v) = 0.39013968
# Courant number: 0.00286834
#
# Time = 1.58000000
# pressure solve iterations =    1
# norm(u) = 1.06355206, norm(v) = 0.38991961
# Courant number: 0.00286924
#
# Time = 1.59000000
# pressure solve iterations =    1
# norm(u) = 1.06347352, norm(v) = 0.38970422
# Courant number: 0.00287011
#
# Time = 1.60000000
# pressure solve iterations =    1
# norm(u) = 1.06339478, norm(v) = 0.38949340
# Courant number: 0.00287096
#
# Time = 1.61000000
# pressure solve iterations =    1
# norm(u) = 1.06331589, norm(v) = 0.38928709
# Courant number: 0.00287178
#
# Time = 1.62000000
# pressure solve iterations =    1
# norm(u) = 1.06323690, norm(v) = 0.38908520
# Courant number: 0.00287258
#
# Time = 1.63000000
# pressure solve iterations =    1
# norm(u) = 1.06315785, norm(v) = 0.38888766
# Courant number: 0.00287335
#
# Time = 1.64000000
# pressure solve iterations =    1
# norm(u) = 1.06307879, norm(v) = 0.38869439
# Courant number: 0.00287411
#
# Time = 1.65000000
# pressure solve iterations =    1
# norm(u) = 1.06299976, norm(v) = 0.38850531
# Courant number: 0.00287484
#
# Time = 1.66000000
# pressure solve iterations =    1
# norm(u) = 1.06292081, norm(v) = 0.38832035
# Courant number: 0.00287555
#
# Time = 1.67000000
# pressure solve iterations =    1
# norm(u) = 1.06284196, norm(v) = 0.38813943
# Courant number: 0.00287624
#
# Time = 1.68000000
# pressure solve iterations =    1
# norm(u) = 1.06276327, norm(v) = 0.38796248
# Courant number: 0.00287691
#
# Time = 1.69000000
# pressure solve iterations =    1
# norm(u) = 1.06268477, norm(v) = 0.38778943
# Courant number: 0.00287756
#
# Time = 1.70000000
# pressure solve iterations =    1
# norm(u) = 1.06260648, norm(v) = 0.38762020
# Courant number: 0.00287819
#
# Time = 1.71000000
# pressure solve iterations =    1
# norm(u) = 1.06252845, norm(v) = 0.38745472
# Courant number: 0.00287880
#
# Time = 1.72000000
# pressure solve iterations =    1
# norm(u) = 1.06245070, norm(v) = 0.38729293
# Courant number: 0.00287940
#
# Time = 1.73000000
# pressure solve iterations =    1
# norm(u) = 1.06237326, norm(v) = 0.38713474
# Courant number: 0.00287997
#
# Time = 1.74000000
# pressure solve iterations =    1
# norm(u) = 1.06229616, norm(v) = 0.38698011
# Courant number: 0.00288053
#
# Time = 1.75000000
# pressure solve iterations =    1
# norm(u) = 1.06221943, norm(v) = 0.38682895
# Courant number: 0.00288107
#
# Time = 1.76000000
# pressure solve iterations =    1
# norm(u) = 1.06214309, norm(v) = 0.38668120
# Courant number: 0.00288160
#
# Time = 1.77000000
# pressure solve iterations =    1
# norm(u) = 1.06206718, norm(v) = 0.38653680
# Courant number: 0.00288211
#
# Time = 1.78000000
# pressure solve iterations =    1
# norm(u) = 1.06199170, norm(v) = 0.38639568
# Courant number: 0.00288260
#
# Time = 1.79000000
# pressure solve iterations =    1
# norm(u) = 1.06191668, norm(v) = 0.38625778
# Courant number: 0.00288308
#
# Time = 1.80000000
# pressure solve iterations =    1
# norm(u) = 1.06184215, norm(v) = 0.38612303
# Courant number: 0.00288354
#
# Time = 1.81000000
# pressure solve iterations =    1
# norm(u) = 1.06176812, norm(v) = 0.38599138
# Courant number: 0.00288399
#
# Time = 1.82000000
# pressure solve iterations =    1
# norm(u) = 1.06169461, norm(v) = 0.38586276
# Courant number: 0.00288442
#
# Time = 1.83000000
# pressure solve iterations =    1
# norm(u) = 1.06162165, norm(v) = 0.38573711
# Courant number: 0.00288485
#
# Time = 1.84000000
# pressure solve iterations =    1
# norm(u) = 1.06154923, norm(v) = 0.38561437
# Courant number: 0.00288525
#
# Time = 1.85000000
# pressure solve iterations =    1
# norm(u) = 1.06147739, norm(v) = 0.38549449
# Courant number: 0.00288565
#
# Time = 1.86000000
# pressure solve iterations =    1
# norm(u) = 1.06140614, norm(v) = 0.38537741
# Courant number: 0.00288603
#
# Time = 1.87000000
# pressure solve iterations =    1
# norm(u) = 1.06133548, norm(v) = 0.38526307
# Courant number: 0.00288640
#
# Time = 1.88000000
# pressure solve iterations =    1
# norm(u) = 1.06126544, norm(v) = 0.38515142
# Courant number: 0.00288676
#
# Time = 1.89000000
# pressure solve iterations =    1
# norm(u) = 1.06119603, norm(v) = 0.38504240
# Courant number: 0.00288710
#
# Time = 1.90000000
# pressure solve iterations =    1
# norm(u) = 1.06112725, norm(v) = 0.38493595
# Courant number: 0.00288744
#
# Time = 1.91000000
# pressure solve iterations =    1
# norm(u) = 1.06105912, norm(v) = 0.38483204
# Courant number: 0.00288776
#
# Time = 1.92000000
# pressure solve iterations =    1
# norm(u) = 1.06099164, norm(v) = 0.38473060
# Courant number: 0.00288807
#
# Time = 1.93000000
# pressure solve iterations =    1
# norm(u) = 1.06092484, norm(v) = 0.38463158
# Courant number: 0.00288838
#
# Time = 1.94000000
# pressure solve iterations =    1
# norm(u) = 1.06085870, norm(v) = 0.38453494
# Courant number: 0.00288867
#
# Time = 1.95000000
# pressure solve iterations =    1
# norm(u) = 1.06079325, norm(v) = 0.38444062
# Courant number: 0.00288895
#
# Time = 1.96000000
# pressure solve iterations =    1
# norm(u) = 1.06072849, norm(v) = 0.38434857
# Courant number: 0.00288922
#
# Time = 1.97000000
# pressure solve iterations =    1
# norm(u) = 1.06066442, norm(v) = 0.38425876
# Courant number: 0.00288948
#
# Time = 1.98000000
# pressure solve iterations =    1
# norm(u) = 1.06060106, norm(v) = 0.38417112
# Courant number: 0.00288974
#
# Time = 1.99000000
# pressure solve iterations =    1
# norm(u) = 1.06053840, norm(v) = 0.38408563
# Courant number: 0.00288998
#
# Time = 2.00000000
# pressure solve iterations =    1
# norm(u) = 1.06047646, norm(v) = 0.38400222
# Courant number: 0.00289022
#
# Time = 2.01000000
# pressure solve iterations =    1
# norm(u) = 1.06041523, norm(v) = 0.38392086
# Courant number: 0.00289045
#
# Time = 2.02000000
# pressure solve iterations =    1
# norm(u) = 1.06035471, norm(v) = 0.38384150
# Courant number: 0.00289067
#
# Time = 2.03000000
# pressure solve iterations =    1
# norm(u) = 1.06029493, norm(v) = 0.38376410
# Courant number: 0.00289088
#
# Time = 2.04000000
# pressure solve iterations =    1
# norm(u) = 1.06023586, norm(v) = 0.38368862
# Courant number: 0.00289108
#
# Time = 2.05000000
# pressure solve iterations =    1
# norm(u) = 1.06017752, norm(v) = 0.38361502
# Courant number: 0.00289128
#
# Time = 2.06000000
# pressure solve iterations =    1
# norm(u) = 1.06011991, norm(v) = 0.38354325
# Courant number: 0.00289147
#
# Time = 2.07000000
# pressure solve iterations =    1
# norm(u) = 1.06006303, norm(v) = 0.38347328
# Courant number: 0.00289165
#
# Time = 2.08000000
# pressure solve iterations =    1
# norm(u) = 1.06000688, norm(v) = 0.38340506
# Courant number: 0.00289183
#
# Time = 2.09000000
# pressure solve iterations =    1
# norm(u) = 1.05995146, norm(v) = 0.38333857
# Courant number: 0.00289200
#
# Time = 2.10000000
# pressure solve iterations =    1
# norm(u) = 1.05989677, norm(v) = 0.38327376
# Courant number: 0.00289216
#
# Time = 2.11000000
# pressure solve iterations =    1
# norm(u) = 1.05984281, norm(v) = 0.38321059
# Courant number: 0.00289232
#
# Time = 2.12000000
# pressure solve iterations =    1
# norm(u) = 1.05978958, norm(v) = 0.38314903
# Courant number: 0.00289247
#
# Time = 2.13000000
# pressure solve iterations =    1
# norm(u) = 1.05973707, norm(v) = 0.38308904
# Courant number: 0.00289261
#
# Time = 2.14000000
# pressure solve iterations =    1
# norm(u) = 1.05968530, norm(v) = 0.38303059
# Courant number: 0.00289275
#
# Time = 2.15000000
# pressure solve iterations =    1
# norm(u) = 1.05963424, norm(v) = 0.38297364
# Courant number: 0.00289289
#
# Time = 2.16000000
# pressure solve iterations =    1
# norm(u) = 1.05958391, norm(v) = 0.38291816
# Courant number: 0.00289301
# Steady state reached at time:  2.169290000005744
# Time taken by calculation =  74.30652904510498

# %%
# set up figure
fig = plt.figure(figsize=(21, 7))
ax1 = fig.add_subplot(121)
cont = ax1.contourf(X,Y,p, cmap=cm.coolwarm)
fig.colorbar(cont)
# don't plot at every gird point - every 5th
ax1.quiver(X[::5,::5],Y[::5,::5],u[::5,::5],v[::5,::5])
ax1.set_xlim(-0.0001, 0.01)
ax1.set_ylim(-0.0001, 0.0051)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - pressure and velocity vectors', fontsize=16)

ax1 = fig.add_subplot(122)
cont = ax1.contourf(X,Y,np.sqrt(u*u+v*v), cmap=cm.coolwarm)
fig.colorbar(cont)
ax1.set_xlim(-0.0001, 0.01)
ax1.set_ylim(-0.0001, 0.0051)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - speed', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pressure driven problem - speed')

# %%
# set up figure
fig = plt.figure(figsize=(21, 7))
ax1 = fig.add_subplot(121)
cont = ax1.contourf(X,Y,T, cmap=cm.coolwarm)
fig.colorbar(cont)
# don't plot at every gird point - every 5th
ax1.set_xlim(-0.001, 0.01)
ax1.set_ylim(-0.0001, 0.005)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$y$', fontsize=16)
ax1.set_title('Pressure driven problem - pressure and velocity vectors', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pressure driven problem - pressure and velocity vectors')

# %%
plot_peclet_number_field(u, v, k, Lx, Ly)

# %%
# Size of rectangular domain
Lx = 0.01
Ly = 0.005
P_max = 0.5

# Number of grid points in each direction, including boundary nodes
Nx = 26
Ny = 13

# hence the mesh spacing
dx = Lx/(Nx-1)
dy = Ly/(Ny-1)

# read the docs to see the ordering that mgrid gives us
X, Y = np.mgrid[0:Nx:1, 0:Ny:1]
X = dx*X
Y = dy*Y

# Define a range of diffusivities and pressure drops to test
diffusivities = [5e-4, 5e-5, 5e-6, 5e-7, 5e-8]  # Example values for k
pressure_drops = [0.1, 0.25, 0.5, 1.0, 2]  # Example values for P_max

# Prepare arrays to store results
results = np.zeros((len(diffusivities), len(pressure_drops)))

# Run simulations for each combination of k and P_max
for i in range(len(diffusivities)):
        # Initialize fields
        u = np.zeros_like(X)
        v = np.zeros_like(X)
        p = np.zeros_like(X)
        T = np.zeros_like(X)

        k = diffusivities[i]
        P_max = pressure_drops[i]

        # Apply Dirichlet BCs to u and v - the code below doesn't touch 
        # these so we can do this once outside the time loop
        u[:, -1] = 0
        u[:, 0] = 0
        u[0, :] = 0
        u[-1, :] = 0
        v[:, -1] = 0
        v[:, 0] = 0
        v[0, :] = 0
        v[-1, :] = 0
        imax = len(u)
        jmax = np.size(u)//imax
        p[0,] = P_max
        p[imax//2:, -1] = 0.0


        # Boundary conditions
        T[0,:] = 20  # Inlet temperature in degrees Celsius
        T[len(T)//2:,-1] = 0.0  #Top boundary
        T[:len(T)//2,-1] = 100
        T[-1,:] = 100  # Right boundary temperature 
        T[1:-1,0] = 100 # bottom boundary temperature

        courant = 0.0005
        dt_min = 1.e-6

        t_end = 3
        # Run the solver
        u, v, p, T = solve_NS_with_Temp_update(u, v, p, T, k, rho, nu, courant, dt_min, t_end, dx, dy, rtol=1.e-6, logs=False, outint=1000)

        # Calculate average outflow temperature
        avg_temp = calculate_average_outflow_temperature(T, u, v, dx, dy)
        results[i] = avg_temp
        print(f"k={k}, P_max={P_max}, Avg Outflow Temp: {avg_temp:.2f} C")

# %%
import matplotlib.pyplot as plt

# Provided data
k_values = [0.0005, 5e-05, 5e-06, 5e-07, 5e-08]  # Diffusivity
P_max_values = [0.1, 0.25, 0.5, 1.0, 2.0]  # Pressure drop
avg_temp_values = [98.27, 96.93, 47.68, 19.92, 20.45]  # Average outflow temperature

# Creating the plot
plt.figure(figsize=(10, 6))

# Plotting the data
for i in range(len(k_values)):
    plt.scatter(P_max_values[i], avg_temp_values[i], label=f'k={k_values[i]:.0e}')

# Adding labels and title
plt.xlabel('Pressure Drop (P_max)')
plt.ylabel('Average Outflow Temperature (°C)')
plt.title('Effect of Diffusivity and Pressure Drop on Outflow Temperature')
plt.legend()

# Showing the plot
plt.show()

# %% [markdown]
# The solution demonstrates a clear relationship between the diffusion coefficient (k), pressure drop (P_max), and the average outflow temperature in a fluid flow scenario governed by the Navier-Stokes equations and an advection-diffusion thermal model. As observed from the data, there are distinct trends:
#
# With an increasing diffusion coefficient (k): The average outflow temperature tends to be higher. This is indicative of a stronger diffusion effect, which in the context of temperature means more effective heat spreading throughout the fluid. A higher k enhances the distribution of thermal energy, thereby raising the overall temperature of the outflowing fluid.
#
# With an increasing pressure drop (P_max): The average outflow temperature shows a decreasing trend. This suggests that higher pressure drop leads to more dynamic flow, enhancing advection (the transport of heat by the motion of the fluid). In such cases, advection can outpace diffusion in influencing the temperature distribution, particularly at higher pressure drops.
#
# The trends align with the conceptual understanding provided by the Péclet number, a dimensionless group indicating the relative effects of advection and diffusion. A low Péclet number (dominated by higher k, lower velocities) suggests that diffusion is the primary mechanism of thermal energy transport, leading to a more uniform and potentially higher temperature distribution. Conversely, a high Péclet number (dominated by lower k, higher velocities, or higher pressure drops leading to more vigorous flow) implies that advection is more influential, possibly resulting in lower outflow temperatures as less time is allowed for heat to diffuse throughout the fluid before being carried away.
#
# Therefore, the observed trends and their alignment with the implications of the Péclet number underscore the interplay between physical parameters in dictating the thermal characteristics of fluid flow.
